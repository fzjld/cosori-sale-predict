# %%
import xgboost as xgb
import os
import seaborn as sns
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, OrdinalEncoder
from sklearn.metrics import mean_squared_error, r2_score
from time import time
from scipy import stats
import joblib
import pickle
import pylab as plt
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold, TimeSeriesSplit
import torch.nn as nn
import lightgbm as lgb
from utils import *
from xgboost import plot_importance
from statsmodels.tsa.stattools import adfuller

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.4f' % x)
np.set_printoptions(suppress=True)
sns.set_style({'font.sans-serif': ['simhei', 'Arial']})   # 解决画图中文乱码

# %matplotlib inline

# %%
data = pd.read_csv('./data.csv', encoding='GBK')
data.data_date = pd.to_datetime(data.data_date)
data.head(1)
# Out:
#    id                               site_id        asin  data_date  \
# 0   1  eb766123-9f24-436e-9117-49c739816794  B07GJBBGHG 2021-01-02
#
#                                        product_title  ordered_revenue  \
# 0  COSORI 5.8QT Electric Hot Air Fryers Oven Oill...      153827.1800
#
#    ordered_revenue_of_total  ordered_revenue_last_year  ordered_units  \
# 0                    0.1300                     1.2600           1284
#
#    ordered_units_of_total  ordered_units_prior_period  \
# 0                  0.0600                     -0.1300
#
#    ordered_units_last_year  subcategory_sales_rank  average_sales_price  \
# 0                   1.2600                  1.0000             119.8000
#
#    average_sales_price_prior_period  glance_views  \
# 0                            0.0000    40220.0000
#
#    change_in_glance_view_prior_period  change_in_gv_last_year  \
# 0                              0.0000                  1.1900
#
#    conversion_rate  rep_oos  rep_oos_of_total  rep_oos_prior_period  \
# 0           0.0300   0.0200            0.1400                0.1500
#
#    lbb_price    create_time    update_time
# 0     0.0000  2021/1/4 6:48  2021/1/4 6:48

# %%
alldata = data[(data.asin == 'B07T2LGN8P')][['data_date',
                                             'ordered_units']].sort_values('data_date')
alldata.shape
# Out:
# (619, 2)

# %%
alldata.head(3).append(alldata.tail(2))
# Out:
#        data_date  ordered_units
# 15975 2019-12-02            184
# 15938 2019-12-03             36
# 15903 2019-12-04             40
# 28666 2021-08-21             75
# 28849 2021-08-22             72

# %%
pd.date_range('2019-12-2', '2021-8-22').shape
# Out:
# (630,)

# %% [markdown]
# 2019-12-2到2021-8-22一共是630天的数据，所以这里少了6天的数据

# %%
# 缺少了多少天的数据
set(pd.date_range('2019-12-2', '2021-8-22')).difference(set(alldata.data_date))
# Out:
# {Timestamp('2020-02-03 00:00:00', freq='D'),
#  Timestamp('2020-02-04 00:00:00', freq='D'),
#  Timestamp('2020-02-05 00:00:00', freq='D'),
#  Timestamp('2020-05-09 00:00:00', freq='D'),
#  Timestamp('2020-05-10 00:00:00', freq='D'),
#  Timestamp('2020-05-11 00:00:00', freq='D'),
#  Timestamp('2020-05-12 00:00:00', freq='D'),
#  Timestamp('2021-01-27 00:00:00', freq='D'),
#  Timestamp('2021-01-31 00:00:00', freq='D'),
#  Timestamp('2021-02-01 00:00:00', freq='D'),
#  Timestamp('2021-02-03 00:00:00', freq='D')}

# %%
# 每天的平均销量
alldata.ordered_units.mean()
# Out:
# 57.21163166397415

# %%
plt.figure(figsize=(15, 5))
plt.xticks(rotation=90)
plt.plot(alldata.data_date, alldata.ordered_units)
plt.plot(alldata.data_date, alldata.ordered_units.rolling(10).mean())

# %%
print(adfuller(alldata.ordered_units, 1))
# Out:
# (-13.011968351838403, 2.556743403968723e-24, 1, 617, {'1%': -3.440992973242412, '5%': -2.8662357332485353, '10%': -2.569270733669741}, 6933.320573424284)

# %% [markdown]
# 序列平稳

# %%
roll_window = alldata.ordered_units.rolling(10, )

# %%
plt.plot(roll_window.mean().values)

# %%
sns.distplot(alldata.ordered_units, fit=stats.norm)
# Out:
# <AxesSubplot:xlabel='ordered_units', ylabel='Density'>

# %%
# 偏度
alldata.ordered_units.skew()
# Out:
# 14.313256816647634

# %%
from scipy.special import boxcox1p
boxcox1p(alldata.ordered_units, 0.21).skew()
# Out:
# -0.5363241647813696

# %%
sns.distplot(boxcox1p(alldata.ordered_units, 0.21), fit=stats.norm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8565f2ebda67> in <module>
# ----> 1 sns.distplot(boxcox1p(alldata.ordered_units, 0.21), fit=stats.norm)
#
# NameError: name 'sns' is not defined

# %% [markdown]
# ## 数据预处理

# %% [markdown]
# ### 异常值，删除小于等于0的数值和离群点

# %%
alldata[alldata.ordered_units <= 0].index
# Out:
# Int64Index([13870, 10363,  6937,  6895,  6853,  6810,  5847, 25206, 25265,
#             25323, 25379, 25497, 25442, 25612, 25554],
#            dtype='int64')

# %%
alldata.drop(alldata[alldata.ordered_units <= 0].index, inplace=True)

# %%
sns.boxplot(alldata.ordered_units)
# Out:
# <AxesSubplot:xlabel='ordered_units'>

# %%
alldata[alldata.ordered_units > 600].index
# Out:
# Int64Index([1682], dtype='int64')

# %%
alldata.drop(alldata[alldata.ordered_units > 600].index, inplace=True)

# %%
alldata.shape
# Out:
# (603, 2)

# %%
alldata.head(1)
# Out:
#        data_date  ordered_units
# 15975 2019-12-02            184

# %% [markdown]
# ### 缺失值

# %%
alldata.isnull().sum()
# Out:
# data_date        0
# ordered_units    0
# dtype: int64

# %% [markdown]
# 无缺失值不用处理

# %% [markdown]
# ### 创造特征

# %%
def create_feature(df):
    # 添加权重特征
    df['weight'] = df.data_date.apply(lambda x: (
    x - pd.to_datetime('2019-12-02')).days)
    df['year'] = df.data_date.dt.year
    df['month'] = df.data_date.dt.month
    df['day'] = df.data_date.dt.day
    df['weekday'] = df.data_date.dt.weekday  # 周几
    df['quarter'] = df.data_date.dt.quarter  # 季度
    df['weekofyear'] = df.data_date.dt.weekofyear
    

    df.drop('data_date', axis=1, inplace=True)
    return df

# %%
alldata = create_feature(alldata)

# %%
alldata.head(3)
# Out:
#        ordered_units  weight  year  month  day  weekday  quarter  weekofyear
# 15975            184       0  2019     12    2        0        4          49
# 15938             36       1  2019     12    3        1        4          49
# 15903             40       2  2019     12    4        2        4          49

# %%
alldata.corr().ordered_units.sort_values()
# Out:
# weekday         -0.0056
# month            0.0237
# quarter          0.0262
# day              0.0531
# weekofyear       0.0842
# year             0.1429
# weight           0.1778
# ordered_units    1.0000
# Name: ordered_units, dtype: float64

# %%
x = alldata.drop('ordered_units', axis=1)
y = alldata['ordered_units']
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.085, random_state=0, shuffle=False)

# %%
x_train.tail(2)
# Out:
#        weight  year  month  day  weekday  quarter  weekofyear
# 25678     576  2021      6   30        2        2          26
# 25796     577  2021      7    1        3        3          26

# %% [markdown]
# ### 编码

# %%
weight_cat = list(range(1000))
year_category = [2019, 2020, 2021, 2022]
month_category = list(range(1, 13))
day_category = list(range(1, 32))
weekday_cat = sorted(x_train.weekday.unique())
quarter_cat = [1, 2, 3, 4]
weekofyear_cat = sorted(x_train.weekofyear.unique())

encoder = OneHotEncoder(sparse=False,
                        categories=[weight_cat, year_category, month_category,
                                    day_category, weekday_cat, quarter_cat, weekofyear_cat],
                        handle_unknown='error')
x_train = encoder.fit_transform(x_train)
x_test = encoder.transform(x_test)
x_train.shape, x_test.shape
# Out:
# ((551, 1111), (52, 1111))

# %%
x_train = pd.DataFrame(x_train, columns=encoder.get_feature_names())
x_test = pd.DataFrame(x_test, columns=encoder.get_feature_names())
x_train.head(1)
# Out:
#     x0_0   x0_1   x0_2   x0_3   x0_4   x0_5   x0_6   x0_7   x0_8   x0_9  \
# 0 1.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x0_10  x0_11  x0_12  x0_13  x0_14  x0_15  x0_16  x0_17  x0_18  x0_19  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x0_20  x0_21  x0_22  x0_23  x0_24  x0_25  x0_26  x0_27  x0_28  x0_29  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x0_30  x0_31  x0_32  x0_33  x0_34  x0_35  x0_36  x0_37  x0_38  x0_39  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x0_40  x0_41  x0_42  x0_43  x0_44  x0_45  x0_46  x0_47  x0_48  x0_49  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x0_50  x0_51  x0_52  x0_53  x0_54  x0_55  x0_56  x0_57  x0_58  x0_59  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x0_60  x0_61  x0_62  x0_63  x0_64  x0_65  x0_66  x0_67  x0_68  x0_69  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x0_70  x0_71  x0_72  x0_73  x0_74  x0_75  x0_76  x0_77  x0_78  x0_79  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x0_80  x0_81  x0_82  x0_83  x0_84  x0_85  x0_86  x0_87  x0_88  x0_89  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x0_90  x0_91  x0_92  x0_93  x0_94  x0_95  x0_96  x0_97  x0_98  x0_99  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x0_100  x0_101  x0_102  x0_103  x0_104  x0_105  x0_106  x0_107  x0_108  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_109  x0_110  x0_111  x0_112  x0_113  x0_114  x0_115  x0_116  x0_117  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_118  x0_119  x0_120  x0_121  x0_122  x0_123  x0_124  x0_125  x0_126  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_127  x0_128  x0_129  x0_130  x0_131  x0_132  x0_133  x0_134  x0_135  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_136  x0_137  x0_138  x0_139  x0_140  x0_141  x0_142  x0_143  x0_144  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_145  x0_146  x0_147  x0_148  x0_149  x0_150  x0_151  x0_152  x0_153  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_154  x0_155  x0_156  x0_157  x0_158  x0_159  x0_160  x0_161  x0_162  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_163  x0_164  x0_165  x0_166  x0_167  x0_168  x0_169  x0_170  x0_171  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_172  x0_173  x0_174  x0_175  x0_176  x0_177  x0_178  x0_179  x0_180  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_181  x0_182  x0_183  x0_184  x0_185  x0_186  x0_187  x0_188  x0_189  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_190  x0_191  x0_192  x0_193  x0_194  x0_195  x0_196  x0_197  x0_198  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_199  x0_200  x0_201  x0_202  x0_203  x0_204  x0_205  x0_206  x0_207  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_208  x0_209  x0_210  x0_211  x0_212  x0_213  x0_214  x0_215  x0_216  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_217  x0_218  x0_219  x0_220  x0_221  x0_222  x0_223  x0_224  x0_225  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_226  x0_227  x0_228  x0_229  x0_230  x0_231  x0_232  x0_233  x0_234  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_235  x0_236  x0_237  x0_238  x0_239  x0_240  x0_241  x0_242  x0_243  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_244  x0_245  x0_246  x0_247  x0_248  x0_249  x0_250  x0_251  x0_252  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_253  x0_254  x0_255  x0_256  x0_257  x0_258  x0_259  x0_260  x0_261  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_262  x0_263  x0_264  x0_265  x0_266  x0_267  x0_268  x0_269  x0_270  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_271  x0_272  x0_273  x0_274  x0_275  x0_276  x0_277  x0_278  x0_279  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_280  x0_281  x0_282  x0_283  x0_284  x0_285  x0_286  x0_287  x0_288  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_289  x0_290  x0_291  x0_292  x0_293  x0_294  x0_295  x0_296  x0_297  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_298  x0_299  x0_300  x0_301  x0_302  x0_303  x0_304  x0_305  x0_306  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_307  x0_308  x0_309  x0_310  x0_311  x0_312  x0_313  x0_314  x0_315  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_316  x0_317  x0_318  x0_319  x0_320  x0_321  x0_322  x0_323  x0_324  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_325  x0_326  x0_327  x0_328  x0_329  x0_330  x0_331  x0_332  x0_333  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_334  x0_335  x0_336  x0_337  x0_338  x0_339  x0_340  x0_341  x0_342  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_343  x0_344  x0_345  x0_346  x0_347  x0_348  x0_349  x0_350  x0_351  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_352  x0_353  x0_354  x0_355  x0_356  x0_357  x0_358  x0_359  x0_360  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_361  x0_362  x0_363  x0_364  x0_365  x0_366  x0_367  x0_368  x0_369  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_370  x0_371  x0_372  x0_373  x0_374  x0_375  x0_376  x0_377  x0_378  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_379  x0_380  x0_381  x0_382  x0_383  x0_384  x0_385  x0_386  x0_387  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_388  x0_389  x0_390  x0_391  x0_392  x0_393  x0_394  x0_395  x0_396  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_397  x0_398  x0_399  x0_400  x0_401  x0_402  x0_403  x0_404  x0_405  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_406  x0_407  x0_408  x0_409  x0_410  x0_411  x0_412  x0_413  x0_414  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_415  x0_416  x0_417  x0_418  x0_419  x0_420  x0_421  x0_422  x0_423  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_424  x0_425  x0_426  x0_427  x0_428  x0_429  x0_430  x0_431  x0_432  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_433  x0_434  x0_435  x0_436  x0_437  x0_438  x0_439  x0_440  x0_441  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_442  x0_443  x0_444  x0_445  x0_446  x0_447  x0_448  x0_449  x0_450  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_451  x0_452  x0_453  x0_454  x0_455  x0_456  x0_457  x0_458  x0_459  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_460  x0_461  x0_462  x0_463  x0_464  x0_465  x0_466  x0_467  x0_468  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_469  x0_470  x0_471  x0_472  x0_473  x0_474  x0_475  x0_476  x0_477  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_478  x0_479  x0_480  x0_481  x0_482  x0_483  x0_484  x0_485  x0_486  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_487  x0_488  x0_489  x0_490  x0_491  x0_492  x0_493  x0_494  x0_495  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_496  x0_497  x0_498  x0_499  x0_500  x0_501  x0_502  x0_503  x0_504  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_505  x0_506  x0_507  x0_508  x0_509  x0_510  x0_511  x0_512  x0_513  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_514  x0_515  x0_516  x0_517  x0_518  x0_519  x0_520  x0_521  x0_522  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_523  x0_524  x0_525  x0_526  x0_527  x0_528  x0_529  x0_530  x0_531  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_532  x0_533  x0_534  x0_535  x0_536  x0_537  x0_538  x0_539  x0_540  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_541  x0_542  x0_543  x0_544  x0_545  x0_546  x0_547  x0_548  x0_549  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_550  x0_551  x0_552  x0_553  x0_554  x0_555  x0_556  x0_557  x0_558  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_559  x0_560  x0_561  x0_562  x0_563  x0_564  x0_565  x0_566  x0_567  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_568  x0_569  x0_570  x0_571  x0_572  x0_573  x0_574  x0_575  x0_576  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_577  x0_578  x0_579  x0_580  x0_581  x0_582  x0_583  x0_584  x0_585  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_586  x0_587  x0_588  x0_589  x0_590  x0_591  x0_592  x0_593  x0_594  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_595  x0_596  x0_597  x0_598  x0_599  x0_600  x0_601  x0_602  x0_603  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_604  x0_605  x0_606  x0_607  x0_608  x0_609  x0_610  x0_611  x0_612  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_613  x0_614  x0_615  x0_616  x0_617  x0_618  x0_619  x0_620  x0_621  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_622  x0_623  x0_624  x0_625  x0_626  x0_627  x0_628  x0_629  x0_630  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_631  x0_632  x0_633  x0_634  x0_635  x0_636  x0_637  x0_638  x0_639  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_640  x0_641  x0_642  x0_643  x0_644  x0_645  x0_646  x0_647  x0_648  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_649  x0_650  x0_651  x0_652  x0_653  x0_654  x0_655  x0_656  x0_657  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_658  x0_659  x0_660  x0_661  x0_662  x0_663  x0_664  x0_665  x0_666  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_667  x0_668  x0_669  x0_670  x0_671  x0_672  x0_673  x0_674  x0_675  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_676  x0_677  x0_678  x0_679  x0_680  x0_681  x0_682  x0_683  x0_684  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_685  x0_686  x0_687  x0_688  x0_689  x0_690  x0_691  x0_692  x0_693  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_694  x0_695  x0_696  x0_697  x0_698  x0_699  x0_700  x0_701  x0_702  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_703  x0_704  x0_705  x0_706  x0_707  x0_708  x0_709  x0_710  x0_711  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_712  x0_713  x0_714  x0_715  x0_716  x0_717  x0_718  x0_719  x0_720  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_721  x0_722  x0_723  x0_724  x0_725  x0_726  x0_727  x0_728  x0_729  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_730  x0_731  x0_732  x0_733  x0_734  x0_735  x0_736  x0_737  x0_738  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_739  x0_740  x0_741  x0_742  x0_743  x0_744  x0_745  x0_746  x0_747  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_748  x0_749  x0_750  x0_751  x0_752  x0_753  x0_754  x0_755  x0_756  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_757  x0_758  x0_759  x0_760  x0_761  x0_762  x0_763  x0_764  x0_765  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_766  x0_767  x0_768  x0_769  x0_770  x0_771  x0_772  x0_773  x0_774  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_775  x0_776  x0_777  x0_778  x0_779  x0_780  x0_781  x0_782  x0_783  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_784  x0_785  x0_786  x0_787  x0_788  x0_789  x0_790  x0_791  x0_792  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_793  x0_794  x0_795  x0_796  x0_797  x0_798  x0_799  x0_800  x0_801  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_802  x0_803  x0_804  x0_805  x0_806  x0_807  x0_808  x0_809  x0_810  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_811  x0_812  x0_813  x0_814  x0_815  x0_816  x0_817  x0_818  x0_819  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_820  x0_821  x0_822  x0_823  x0_824  x0_825  x0_826  x0_827  x0_828  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_829  x0_830  x0_831  x0_832  x0_833  x0_834  x0_835  x0_836  x0_837  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_838  x0_839  x0_840  x0_841  x0_842  x0_843  x0_844  x0_845  x0_846  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_847  x0_848  x0_849  x0_850  x0_851  x0_852  x0_853  x0_854  x0_855  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_856  x0_857  x0_858  x0_859  x0_860  x0_861  x0_862  x0_863  x0_864  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_865  x0_866  x0_867  x0_868  x0_869  x0_870  x0_871  x0_872  x0_873  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_874  x0_875  x0_876  x0_877  x0_878  x0_879  x0_880  x0_881  x0_882  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_883  x0_884  x0_885  x0_886  x0_887  x0_888  x0_889  x0_890  x0_891  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_892  x0_893  x0_894  x0_895  x0_896  x0_897  x0_898  x0_899  x0_900  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_901  x0_902  x0_903  x0_904  x0_905  x0_906  x0_907  x0_908  x0_909  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_910  x0_911  x0_912  x0_913  x0_914  x0_915  x0_916  x0_917  x0_918  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_919  x0_920  x0_921  x0_922  x0_923  x0_924  x0_925  x0_926  x0_927  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_928  x0_929  x0_930  x0_931  x0_932  x0_933  x0_934  x0_935  x0_936  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_937  x0_938  x0_939  x0_940  x0_941  x0_942  x0_943  x0_944  x0_945  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_946  x0_947  x0_948  x0_949  x0_950  x0_951  x0_952  x0_953  x0_954  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_955  x0_956  x0_957  x0_958  x0_959  x0_960  x0_961  x0_962  x0_963  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_964  x0_965  x0_966  x0_967  x0_968  x0_969  x0_970  x0_971  x0_972  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_973  x0_974  x0_975  x0_976  x0_977  x0_978  x0_979  x0_980  x0_981  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_982  x0_983  x0_984  x0_985  x0_986  x0_987  x0_988  x0_989  x0_990  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_991  x0_992  x0_993  x0_994  x0_995  x0_996  x0_997  x0_998  x0_999  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x1_2019  x1_2020  x1_2021  x1_2022   x2_1   x2_2   x2_3   x2_4   x2_5  \
# 0   1.0000   0.0000   0.0000   0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#     x2_6   x2_7   x2_8   x2_9  x2_10  x2_11  x2_12   x3_1   x3_2   x3_3  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 1.0000 0.0000 1.0000 0.0000
#
#     x3_4   x3_5   x3_6   x3_7   x3_8   x3_9  x3_10  x3_11  x3_12  x3_13  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x3_14  x3_15  x3_16  x3_17  x3_18  x3_19  x3_20  x3_21  x3_22  x3_23  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x3_24  x3_25  x3_26  x3_27  x3_28  x3_29  x3_30  x3_31   x4_0   x4_1  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 1.0000 0.0000
#
#     x4_2   x4_3   x4_4   x4_5   x4_6   x5_1   x5_2   x5_3   x5_4   x6_1  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 1.0000 0.0000
#
#     x6_2   x6_3   x6_4   x6_5   x6_6   x6_7   x6_8   x6_9  x6_10  x6_11  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x6_12  x6_13  x6_14  x6_15  x6_16  x6_17  x6_18  x6_19  x6_20  x6_21  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x6_22  x6_23  x6_24  x6_25  x6_26  x6_27  x6_28  x6_29  x6_30  x6_31  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x6_32  x6_33  x6_34  x6_35  x6_36  x6_37  x6_38  x6_39  x6_40  x6_41  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x6_42  x6_43  x6_44  x6_45  x6_46  x6_47  x6_48  x6_49  x6_50  x6_51  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 1.0000 0.0000 0.0000
#
#    x6_52  x6_53
# 0 0.0000 0.0000

# %% [markdown]
# ## 训练

# %% [markdown]
# ### sklearn api

# %%
xgbr = XGBRegressor(n_estimators=200,
                    learning_rate=0.35,
                    max_depth=7,
                    subsample=0.6,
                    colsample_bytree=0.7,
                    objective='reg:squarederror',
                    base_score=0.5,
                    gamma=1,
                    n_jobs=8, verbosity=1)

# %%
ts = time()
kf = KFold()
print(cross_val_score(xgbr, x_train, y_train, cv=kf))
time() - ts
# Out:
# [-1.80647862 -0.30407196 -0.21800804 -0.87247112 -0.96152316]
# 4.7945075035095215

# %%
ts = time()
tscv = TimeSeriesSplit(10)
print(cross_val_score(xgbr, x_train, y_train, cv=tscv))
time() - ts
# Out:
# [ 0.19352668 -0.1198146  -0.51547012 -0.66683017  0.16459761 -0.15180886
#  -2.0250308  -3.18961857 -0.79042502 -1.33736953]
# 8.355094194412231

# %%
xgbr.fit(x_train, y_train, eval_set=[(x_train, y_train), (x_test, y_test)],
         early_stopping_rounds=20, verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=1, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.35, max_delta_step=0, max_depth=7,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=200, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=0.6,
#              tree_method='exact', validate_parameters=1, verbosity=1)

# %%
# 网格搜索
# params_grid = {'learning_rate': np.arange(0, 1, 0.05)}

# params_grid = {'max_depth': range(0, 8, 1)}

# params_grid = {'subsample': np.arange(0, 1, 0.05)}
params_grid = {'colsample_bytree': np.arange(0, 1, 0.05)}

gridCV = GridSearchCV(xgbr, params_grid, cv=5, scoring='r2', n_jobs=8)

ts = time()
gridCV.fit(x_train, y_train)
print(time() - ts)
gridCV.best_params_, gridCV.best_score_

# %%
result = xgbr.evals_result()
plt.plot(result['validation_0']['rmse'])
plt.plot(result['validation_1']['rmse'])

# %% [markdown]
# ## 测试

# %% [markdown]
# ### sklearn api

# %%
y_pred = xgbr.predict(x_test)
print('metrics1: {:.3f}\nmetrics2: {:.3f}\nr2: {:.3f}'.format(metrics1(y_test, y_pred),
                                                              metrics2(
                                                                  y_test, y_pred),
                                                              r2_score(y_test, y_pred)))
# Out:
# metrics1: 0.970
# metrics2: 0.609
# r2: 0.002

# %%
plt.figure(figsize=(15, 4))
plt.plot(y_test.values, label='true')
plt.plot(y_pred, label='predict')
plt.xticks(rotation=90)
plt.grid()
plt.legend(fontsize=15)

# %%
date_pred = pd.DataFrame({'data_date': pd.date_range('2021-8-23', periods=30)})

# %%
alldata
# Out:
#        ordered_units  weight  year  month  day  weekday  quarter  weekofyear
# 8968               5     194  2020      6   13        5        2          24
# 8920              16     195  2020      6   14        6        2          24
# 8881              14     196  2020      6   15        0        2          25
# 8841              19     197  2020      6   16        1        2          25
# 8801              19     198  2020      6   17        2        2          25
# ...              ...     ...   ...    ...  ...      ...      ...         ...
# 28723            152     625  2021      8   18        2        3          33
# 28602            130     626  2021      8   19        3        3          33
# 28544            115     627  2021      8   20        4        3          33
# 28664            101     628  2021      8   21        5        3          33
# 28846            129     629  2021      8   22        6        3          33
#
# [425 rows x 8 columns]

# %%
create_feature(date_pred)
# Out:
#     weight  year  month  day  weekday  quarter  weekofyear
# 0      630  2021      8   23        0        3          34
# 1      631  2021      8   24        1        3          34
# 2      632  2021      8   25        2        3          34
# 3      633  2021      8   26        3        3          34
# 4      634  2021      8   27        4        3          34
# 5      635  2021      8   28        5        3          34
# 6      636  2021      8   29        6        3          34
# 7      637  2021      8   30        0        3          35
# 8      638  2021      8   31        1        3          35
# 9      639  2021      9    1        2        3          35
# 10     640  2021      9    2        3        3          35
# 11     641  2021      9    3        4        3          35
# 12     642  2021      9    4        5        3          35
# 13     643  2021      9    5        6        3          35
# 14     644  2021      9    6        0        3          36
# 15     645  2021      9    7        1        3          36
# 16     646  2021      9    8        2        3          36
# 17     647  2021      9    9        3        3          36
# 18     648  2021      9   10        4        3          36
# 19     649  2021      9   11        5        3          36
# 20     650  2021      9   12        6        3          36
# 21     651  2021      9   13        0        3          37
# 22     652  2021      9   14        1        3          37
# 23     653  2021      9   15        2        3          37
# 24     654  2021      9   16        3        3          37
# 25     655  2021      9   17        4        3          37
# 26     656  2021      9   18        5        3          37
# 27     657  2021      9   19        6        3          37
# 28     658  2021      9   20        0        3          38
# 29     659  2021      9   21        1        3          38

# %%
date_pred = encoder.transform(date_pred)

# %%
pred = xgbr.predict(date_pred)

# %%
pred
# Out:
# array([153.02022 , 165.89987 , 136.37695 ,  97.53572 , 138.09909 ,
#        143.99847 , 152.29909 , 157.29836 , 144.26472 ,  93.049324,
#         90.73743 , 102.003044,  94.121605, 116.72564 , 151.30339 ,
#        138.52554 , 151.34003 , 147.40532 , 154.08519 , 143.84673 ,
#        159.80147 , 160.32239 , 154.55843 , 153.87544 , 160.85028 ,
#        152.48506 , 145.30484 , 155.03554 , 152.9371  , 154.25227 ],
#       dtype=float32)

# %%
plt.plot(pred)

# %%
a = xgbr.get_booster().get_score(importance_type='gain')
# len(a)
sorted(a.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('x6_51', 57550.03545738462),
#  ('x2_12', 33535.52279131249),
#  ('x0_317', 28840.72957630769),
#  ('x0_394', 27196.3125),
#  ('x0_364', 19281.603190058817),
#  ('x6_50', 18164.34922526154),
#  ('x6_49', 17047.99481),
#  ('x0_366', 16330.354646666667),
#  ('x0_368', 15625.864258),
#  ('x0_392', 15596.2960665),
#  ('x2_5', 13098.1095535),
#  ('x0_395', 12970.7559355),
#  ('x6_27', 11978.52979925),
#  ('x0_369', 11519.547344499999),
#  ('x1_2019', 11337.003072231875),
#  ('x6_40', 11136.1875),
#  ('x1_2021', 10496.735829473077),
#  ('x2_1', 8611.159353000001),
#  ('x2_11', 8572.554775485714),
#  ('x3_20', 6868.77169585),
#  ('x6_45', 5731.8494875),
#  ('x0_370', 4741.171287454545),
#  ('x6_48', 4449.624376111111),
#  ('x0_3', 4224.637596142858),
#  ('x0_385', 4224.14493125),
#  ('x6_44', 4187.2996496666665),
#  ('x2_9', 4157.407201666666),
#  ('x6_19', 4016.633325),
#  ('x2_8', 3636.5604492666666),
#  ('x2_7', 3608.376940855556),
#  ('x0_34', 3582.4575056000003),
#  ('x0_517', 3284.42433),
#  ('x6_18', 3245.8186780000005),
#  ('x5_3', 3233.2013354),
#  ('x0_212', 3040.111108714286),
#  ('x6_42', 3036.7137422499995),
#  ('x6_29', 2939.8770776666665),
#  ('x4_6', 2929.906363381818),
#  ('x3_2', 2861.311371961539),
#  ('x0_380', 2704.5639675),
#  ('x0_240', 2647.57227),
#  ('x3_5', 2479.690521281667),
#  ('x6_31', 2457.6682299999998),
#  ('x6_43', 2419.1850875),
#  ('x1_2020', 2367.2489234496875),
#  ('x6_2', 2237.9965570000004),
#  ('x3_24', 2235.783581272857),
#  ('x0_230', 2175.8032647),
#  ('x2_6', 2064.7164805333337),
#  ('x6_3', 1979.542452),
#  ('x5_4', 1939.60321004),
#  ('x6_13', 1857.558395),
#  ('x3_25', 1835.5400298333334),
#  ('x6_14', 1807.8886485750002),
#  ('x0_386', 1794.5359578750001),
#  ('x0_568', 1651.3137712857144),
#  ('x0_424', 1600.95215),
#  ('x6_30', 1538.7510653333331),
#  ('x3_19', 1495.6386733333331),
#  ('x0_234', 1456.2821),
#  ('x0_6', 1443.89233),
#  ('x0_213', 1417.979),
#  ('x0_376', 1409.8872104285715),
#  ('x3_14', 1388.7278919333332),
#  ('x4_2', 1306.5024178222222),
#  ('x0_60', 1288.579984),
#  ('x0_236', 1272.5562907),
#  ('x5_2', 1270.6066844285713),
#  ('x6_4', 1262.7195646666667),
#  ('x0_367', 1197.0575006666666),
#  ('x0_21', 1150.1306155),
#  ('x0_328', 1086.27734),
#  ('x3_31', 1073.580853),
#  ('x0_106', 1070.53223),
#  ('x0_242', 1053.5248115),
#  ('x2_10', 1041.7087565),
#  ('x4_4', 1038.1197677266669),
#  ('x0_2', 983.3700212499999),
#  ('x3_30', 920.6544903833334),
#  ('x0_359', 916.8127020000001),
#  ('x3_11', 913.70503225),
#  ('x6_52', 900.3728521250002),
#  ('x0_382', 882.385969925),
#  ('x4_0', 876.3340700923077),
#  ('x5_1', 876.0029121857144),
#  ('x0_35', 874.5831289999999),
#  ('x0_379', 817.5051905),
#  ('x0_432', 817.18512),
#  ('x0_43', 815.5523469999999),
#  ('x6_15', 809.8251533333333),
#  ('x4_3', 803.5137026875),
#  ('x0_363', 796.0925192000001),
#  ('x0_157', 791.6473835),
#  ('x6_9', 782.2131475),
#  ('x6_41', 778.9819832000001),
#  ('x3_12', 745.8380455),
#  ('x4_5', 731.7467801124999),
#  ('x0_224', 727.2161575),
#  ('x3_22', 726.4933783),
#  ('x0_384', 725.457687625),
#  ('x6_12', 716.1121205000001),
#  ('x0_90', 709.330734),
#  ('x0_36', 702.0998372500001),
#  ('x6_6', 675.220337),
#  ('x0_323', 672.6593429999999),
#  ('x0_409', 664.7178353333334),
#  ('x6_17', 633.8302981999999),
#  ('x0_358', 630.1218662666666),
#  ('x0_89', 627.4585063333334),
#  ('x0_244', 625.8163453333333),
#  ('x0_9', 622.3855265000001),
#  ('x0_72', 621.1616096),
#  ('x3_29', 610.438202),
#  ('x3_18', 606.4230000000001),
#  ('x6_5', 578.783683),
#  ('x2_2', 574.4917912714286),
#  ('x0_228', 570.978149),
#  ('x6_1', 553.50855725),
#  ('x6_8', 549.82782),
#  ('x0_160', 541.3233172500001),
#  ('x0_28', 540.6412125),
#  ('x0_248', 540.3879577999999),
#  ('x0_110', 535.751785),
#  ('x0_133', 530.4264525),
#  ('x0_37', 528.81244675),
#  ('x0_125', 524.097778),
#  ('x0_391', 519.6777345),
#  ('x0_24', 518.4467916666667),
#  ('x0_321', 516.93475345),
#  ('x3_13', 514.78493495),
#  ('x0_135', 506.60015899999996),
#  ('x0_69', 505.785522),
#  ('x0_388', 501.3103306833334),
#  ('x0_241', 497.315796),
#  ('x0_383', 495.7492985),
#  ('x0_159', 490.8905985),
#  ('x0_91', 482.446426),
#  ('x0_13', 476.8125),
#  ('x0_420', 471.5823873333334),
#  ('x0_111', 471.5040055),
#  ('x6_53', 444.9974485999999),
#  ('x0_195', 442.708252),
#  ('x4_1', 424.73450150166667),
#  ('x0_146', 421.9832579999999),
#  ('x3_21', 417.378348),
#  ('x0_156', 413.25),
#  ('x3_8', 413.15124),
#  ('x2_3', 409.9125675),
#  ('x6_16', 407.646393),
#  ('x0_17', 406.666382),
#  ('x0_360', 403.444946),
#  ('x0_142', 399.89454319999993),
#  ('x0_239', 399.731323),
#  ('x0_326', 397.077271),
#  ('x0_314', 392.950317),
#  ('x0_186', 389.50167799999997),
#  ('x0_65', 384.63487250000003),
#  ('x0_357', 376.6267272),
#  ('x6_20', 376.60914625000004),
#  ('x0_431', 375.179047),
#  ('x0_10', 374.198975),
#  ('x0_144', 357.533203),
#  ('x0_161', 355.118408),
#  ('x6_21', 354.40625),
#  ('x0_405', 353.47015375),
#  ('x0_15', 352.926056),
#  ('x0_16', 352.52844200000004),
#  ('x3_4', 352.36108952999996),
#  ('x0_61', 350.32214350000004),
#  ('x3_27', 342.59731674999995),
#  ('x0_308', 341.88435350000003),
#  ('x0_389', 341.6214295),
#  ('x0_411', 341.61203),
#  ('x0_49', 338.404541),
#  ('x0_22', 334.0443115),
#  ('x0_39', 331.7957152),
#  ('x6_10', 330.61703124999997),
#  ('x2_4', 327.55823167399996),
#  ('x0_390', 326.52262875),
#  ('x0_153', 322.928772),
#  ('x3_17', 320.16739665),
#  ('x0_184', 317.002014),
#  ('x0_175', 316.578735),
#  ('x0_149', 314.372314),
#  ('x0_430', 305.98150599999997),
#  ('x3_15', 304.813289625),
#  ('x3_7', 304.37565272500007),
#  ('x0_547', 295.546875),
#  ('x0_610', 294.468821),
#  ('x0_611', 291.31744365000003),
#  ('x0_418', 291.039421),
#  ('x6_35', 290.9327545),
#  ('x3_10', 289.7529321525),
#  ('x0_275', 287.1425325),
#  ('x6_28', 284.053101),
#  ('x0_67', 283.732056),
#  ('x0_402', 282.2924045),
#  ('x0_378', 281.233887),
#  ('x0_226', 280.7059635),
#  ('x0_480', 280.19519),
#  ('x3_28', 277.25519565),
#  ('x0_77', 275.160767),
#  ('x0_165', 274.90625),
#  ('x0_27', 273.0870463333333),
#  ('x0_140', 264.144958),
#  ('x0_238', 264.0142773333333),
#  ('x3_1', 262.520081),
#  ('x0_128', 257.574219),
#  ('x0_79', 257.507248),
#  ('x0_26', 257.4859823333333),
#  ('x0_215', 254.329712),
#  ('x0_51', 250.437927),
#  ('x0_117', 250.040771),
#  ('x0_503', 246.91452),
#  ('x0_103', 239.534912),
#  ('x0_235', 238.413025),
#  ('x0_203', 237.9303998),
#  ('x0_311', 236.00036640000002),
#  ('x0_118', 226.640259),
#  ('x0_196', 225.903198),
#  ('x0_29', 223.381226),
#  ('x0_148', 220.60406115),
#  ('x0_519', 218.960449),
#  ('x0_362', 216.56079850000003),
#  ('x0_515', 216.287964),
#  ('x0_374', 213.350136),
#  ('x0_263', 212.38623),
#  ('x0_457', 210.772217),
#  ('x0_232', 210.15545633333332),
#  ('x0_286', 209.115723),
#  ('x0_522', 208.95459),
#  ('x3_3', 208.18747823333334),
#  ('x0_7', 207.4726562),
#  ('x0_604', 207.464966),
#  ('x0_613', 207.25087),
#  ('x6_24', 206.924011),
#  ('x0_88', 205.94016249999999),
#  ('x0_348', 204.737305),
#  ('x0_421', 204.46936),
#  ('x0_145', 201.361481),
#  ('x0_211', 196.34020249999998),
#  ('x0_255', 180.839371),
#  ('x0_355', 177.241241),
#  ('x6_25', 176.06042493333334),
#  ('x0_183', 174.897766),
#  ('x0_416', 172.8125),
#  ('x0_86', 170.753113),
#  ('x0_19', 170.6065065),
#  ('x0_113', 167.946808),
#  ('x6_36', 166.587402),
#  ('x0_202', 166.53436299999998),
#  ('x0_42', 165.788086),
#  ('x0_208', 162.630188),
#  ('x0_351', 162.443604),
#  ('x0_518', 162.2360304),
#  ('x6_34', 161.656769),
#  ('x0_523', 160.23226306666666),
#  ('x0_120', 155.17627),
#  ('x0_486', 151.85970275),
#  ('x0_302', 151.774902),
#  ('x0_307', 150.6134645),
#  ('x3_6', 148.03613265),
#  ('x0_96', 146.014572),
#  ('x0_356', 143.371246),
#  ('x0_279', 143.124329),
#  ('x0_460', 141.85434),
#  ('x0_163', 138.938812),
#  ('x0_442', 137.337891),
#  ('x0_428', 137.21869893333334),
#  ('x0_95', 128.534118805),
#  ('x0_579', 124.134094),
#  ('x0_4', 122.882813),
#  ('x0_23', 120.308128),
#  ('x0_200', 117.82067889999999),
#  ('x0_32', 117.74305),
#  ('x0_587', 117.351135),
#  ('x0_581', 116.840149),
#  ('x0_162', 116.3093719),
#  ('x0_20', 116.0),
#  ('x0_305', 113.946655),
#  ('x0_303', 111.4004518),
#  ('x0_12', 111.255371),
#  ('x0_309', 111.24386584999999),
#  ('x0_339', 108.555984),
#  ('x0_319', 100.45996103333333),
#  ('x0_257', 98.0969999),
#  ('x0_18', 96.59652725000001),
#  ('x0_31', 96.02688584999999),
#  ('x0_496', 91.8560181),
#  ('x0_267', 91.6972656),
#  ('x0_563', 91.3206177),
#  ('x0_603', 88.1646729),
#  ('x0_511', 87.26211619),
#  ('x0_353', 86.7285156),
#  ('x0_334', 83.10568225),
#  ('x0_537', 77.5911255),
#  ('x0_513', 77.0584566),
#  ('x0_336', 72.6505281),
#  ('x0_201', 70.4767419),
#  ('x0_495', 70.4527435),
#  ('x0_287', 68.7867126),
#  ('x0_467', 68.3644409),
#  ('x0_476', 66.4820557),
#  ('x6_26', 66.3916992),
#  ('x0_152', 63.5942269),
#  ('x0_164', 63.1420631),
#  ('x0_456', 62.7617188),
#  ('x0_112', 59.2871094),
#  ('x0_25', 59.1419678),
#  ('x0_375', 53.7197266),
#  ('x0_41', 52.8378487),
#  ('x0_510', 51.6807938),
#  ('x0_535', 51.458374),
#  ('x0_87', 49.89054255),
#  ('x0_124', 48.567749),
#  ('x0_450', 48.195770249999995),
#  ('x0_315', 46.5684814),
#  ('x0_502', 46.4525986),
#  ('x0_533', 46.3648071),
#  ('x0_614', 45.1876984),
#  ('x0_548', 44.6841278),
#  ('x0_444', 43.2062378),
#  ('x0_554', 43.1311035),
#  ('x0_341', 40.049593915),
#  ('x0_5', 39.875),
#  ('x0_84', 39.5894165),
#  ('x3_23', 39.57270049666666),
#  ('x0_85', 37.3444824),
#  ('x0_527', 35.9355354),
#  ('x0_132', 35.7618408),
#  ('x0_344', 34.5748901),
#  ('x0_595', 30.1550293),
#  ('x0_584', 28.3614807),
#  ('x0_401', 27.9045582),
#  ('x0_499', 26.9883251),
#  ('x0_190', 25.59602354333333),
#  ('x0_562', 25.3386345),
#  ('x0_11', 24.5573444),
#  ('x0_30', 24.2312622),
#  ('x0_92', 19.6519547),
#  ('x0_372', 17.6254272),
#  ('x0_273', 13.928894),
#  ('x0_436', 12.5521374),
#  ('x0_468', 12.5333862),
#  ('x0_33', 12.4165649),
#  ('x0_583', 12.07168199),
#  ('x0_552', 11.49952315),
#  ('x0_491', 10.8031788),
#  ('x0_482', 10.7745972),
#  ('x0_530', 10.5413952),
#  ('x0_447', 8.63079834),
#  ('x0_192', 8.43984985),
#  ('x0_266', 8.09664536),
#  ('x0_138', 6.65640306),
#  ('x0_276', 6.16742039),
#  ('x0_127', 4.54870605),
#  ('x0_62', 3.98361206),
#  ('x0_50', 2.46933937),
#  ('x0_617', 1.46417594)]

# %% [markdown]
# ### xgboost api

# %%
dtest = xgb.DMatrix(x_test, y_test)

# %%
y_pred = model.predict(dtest)
print('metrics1: {:.3f}\nmetrics2: {:.3f}\nr2: {:.3f}'.format(metrics1(y_test, y_pred),
                                                              metrics2(
                                                                  y_test, y_pred),
                                                              r2_score(y_test, y_pred)))
# Out:
# metrics1: 0.939
# metrics2: 0.732
# r2: 0.858

# %%
plt.figure(figsize=(15, 4))
plt.plot(y_test.values, label='true')
plt.plot(y_pred, label='predict')
plt.xticks(rotation=90)
plt.grid()
plt.legend()

# %%
model.get_score(importance_type='gain')

# %%
xgb.to_graphviz(model, num_trees=0)

# %%
import xgboost
from xgboost import XGBClassifier
from sklearn.datasets import load_iris

iris = load_iris()
x, y = iris.data, iris.target
model = XGBClassifier()
model.fit(x, y)
# 如果输入是没有表头的array,会自动以f1,f2开始,需要更换表头
# 画树结构图的时候也需要替换表头

model.get_booster().feature_names = iris.feature_names
# max_num_features指定排名最靠前的多少特征
# height=0.2指定柱状图每个柱子的粗细,默认是0.2
# importance_type='weight'默认是用特征子树中的出现次数(被选择次数),还有"gain"和"cover"
xgboost.plot_importance(model, max_num_features=5, importance_type='gain')

# f_score就是feature score
model.feature_importances_  # 这里的特征重要性就是gain进行归一化之后的值

# %%
model.feature_importances_.sum()

# %%
2.9918/(2.9918+1.3149+0.0727+0.0424)

# %%
xgb.to_graphviz(model, num_trees=1)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(max_depth=2)

# %%
dt.fit(x, y)

# %%
import graphviz
from sklearn import tree
import pydotplus
from IPython.display import Image

# %%
# 对于决策树来说，特征重要性就等于这个特征分裂的时候的总信息增益，这个特征有可能分裂，加到一起就行
dt.feature_importances_

# %%
dot = tree.export_graphviz(dt)
graph = pydotplus.graph_from_dot_data(dot)
Image(graph.create_png())
