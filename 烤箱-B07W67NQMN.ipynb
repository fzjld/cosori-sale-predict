# %%
import xgboost as xgb
import os
import seaborn as sns
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, OrdinalEncoder
from sklearn.metrics import mean_squared_error, r2_score
from time import time
from scipy import stats
import joblib
import pickle
import pylab as plt
from sklearn.model_selection import cross_val_score, GridSearchCV
import torch.nn as nn
import lightgbm as lgb
from utils import *
from xgboost import plot_importance


import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.4f' % x)
np.set_printoptions(suppress=True)
sns.set_style({'font.sans-serif': ['simhei', 'Arial']})   # 解决画图中文乱码

# %matplotlib inline

# %%
data = pd.read_csv('./data.csv', encoding='GBK')
data.data_date = pd.to_datetime(data.data_date)
data.head(1)
# Out:
#    id                               site_id        asin  data_date  \
# 0   1  eb766123-9f24-436e-9117-49c739816794  B07GJBBGHG 2021-01-02
#
#                                        product_title  ordered_revenue  \
# 0  COSORI 5.8QT Electric Hot Air Fryers Oven Oill...      153827.1800
#
#    ordered_revenue_of_total  ordered_revenue_last_year  ordered_units  \
# 0                    0.1300                     1.2600           1284
#
#    ordered_units_of_total  ordered_units_prior_period  \
# 0                  0.0600                     -0.1300
#
#    ordered_units_last_year  subcategory_sales_rank  average_sales_price  \
# 0                   1.2600                  1.0000             119.8000
#
#    average_sales_price_prior_period  glance_views  \
# 0                            0.0000    40220.0000
#
#    change_in_glance_view_prior_period  change_in_gv_last_year  \
# 0                              0.0000                  1.1900
#
#    conversion_rate  rep_oos  rep_oos_of_total  rep_oos_prior_period  \
# 0           0.0300   0.0200            0.1400                0.1500
#
#    lbb_price    create_time    update_time
# 0     0.0000  2021/1/4 6:48  2021/1/4 6:48

# %%
alldata = data[(data.asin == 'B07W67NQMN')][['data_date',
                                             'ordered_units']].sort_values('data_date')
alldata.shape
# Out:
# (618, 2)

# %%
alldata.head(2).append(alldata.tail(2))
# Out:
#        data_date  ordered_units
# 15971 2019-12-02            308
# 15936 2019-12-03             58
# 28667 2021-08-21             34
# 28848 2021-08-22             45

# %%
pd.date_range('2019-12-2', '2021-8-22').shape
# Out:
# (630,)

# %% [markdown]
# 2019-12-2到2021-8-22一共是630天的数据，所以这里少了6天的数据

# %%
# 缺少了多少天的数据
set(pd.date_range('2019-12-2', '2021-8-22')).difference(set(alldata.data_date))
# Out:
# {Timestamp('2020-01-26 00:00:00', freq='D'),
#  Timestamp('2020-01-27 00:00:00', freq='D'),
#  Timestamp('2020-07-07 00:00:00', freq='D'),
#  Timestamp('2020-07-08 00:00:00', freq='D'),
#  Timestamp('2020-07-09 00:00:00', freq='D'),
#  Timestamp('2020-07-10 00:00:00', freq='D'),
#  Timestamp('2020-07-11 00:00:00', freq='D'),
#  Timestamp('2020-07-12 00:00:00', freq='D'),
#  Timestamp('2021-01-27 00:00:00', freq='D'),
#  Timestamp('2021-01-31 00:00:00', freq='D'),
#  Timestamp('2021-02-01 00:00:00', freq='D'),
#  Timestamp('2021-02-03 00:00:00', freq='D')}

# %%
# 每天的平均销量
alldata.mean()
# Out:
# ordered_units   87.4773
# dtype: float64

# %%
plt.figure(figsize=(15, 5))
plt.xticks(rotation=90)
plt.plot(alldata.data_date, alldata.ordered_units)

# %%
sns.distplot(alldata.ordered_units, fit=stats.norm)
# Out:
# <AxesSubplot:xlabel='ordered_units', ylabel='Density'>

# %%
alldata.ordered_units.skew(), np.log1p(alldata.ordered_units).skew()
# Out:
# (7.5340006644908195, -3.616558075453425)

# %%
from scipy.special import boxcox1p
boxcox1p(alldata.ordered_units, 0.21).skew()
# Out:
# 0.022899662729770277

# %%
sns.distplot(boxcox1p(alldata.ordered_units, 0.21), fit=stats.norm)
# Out:
# <AxesSubplot:xlabel='ordered_units', ylabel='Density'>

# %% [markdown]
# ## 数据预处理

# %% [markdown]
# ### 异常值，删除小于等于0的数值和离群点

# %%
alldata[alldata.ordered_units <= 0].index
# Out:
# Int64Index([14156, 8080, 7059, 6974, 6936], dtype='int64')

# %%
alldata.drop(alldata[alldata.ordered_units <= 0].index, inplace=True)

# %%
sns.boxplot(alldata.ordered_units)
# Out:
# <AxesSubplot:xlabel='ordered_units'>

# %%
alldata[alldata.ordered_units > 800].index
# Out:
# Int64Index([14191, 3925, 25154], dtype='int64')

# %%
alldata.drop(alldata[alldata.ordered_units > 700].index, inplace=True)

# %%
alldata.shape
# Out:
# (610, 2)

# %% [markdown]
# ### 设置样本权重

# %%
alldata['weight'] = alldata.data_date.apply(lambda x: (
    x - pd.to_datetime('2019-12-02')).days)

# %%
alldata.head(1)
# Out:
#        data_date  ordered_units  weight
# 15971 2019-12-02            308       0

# %% [markdown]
# ### 缺失值

# %%
alldata.isnull().sum()
# Out:
# data_date        0
# ordered_units    0
# weight           0
# dtype: int64

# %% [markdown]
# 无缺失值不用处理

# %% [markdown]
# ### 创造特征

# %%
def create_feature(df):
    df['year'] = df.data_date.dt.year
    df['month'] = df.data_date.dt.month
    df['day'] = df.data_date.dt.day
    df['weekday'] = df.data_date.dt.weekday  # 周几
    df['quarter'] = df.data_date.dt.quarter  # 季度
    df['weekofyear'] = df.data_date.dt.weekofyear

    df.drop('data_date', axis=1, inplace=True)
    return df

# %%
alldata = create_feature(alldata)

# %%
alldata.head(3)
# Out:
#        ordered_units  weight  year  month  day  weekday  quarter  weekofyear
# 15971            308       0  2019     12    2        0        4          49
# 15936             58       1  2019     12    3        1        4          49
# 15899             80       2  2019     12    4        2        4          49

# %%
x = alldata.drop('ordered_units', axis=1)
y = alldata['ordered_units']
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.1, random_state=0)

# %%
x_train.head(2)
# Out:
#        weight  year  month  day  weekday  quarter  weekofyear
# 22675     523  2021      5    8        5        2          18
# 16988     416  2021      1   21        3        1           3

# %% [markdown]
# ### 编码

# %%
weight_cat = list(range(1, 1000))
year_category = [2019, 2020, 2021, 2022]
month_category = list(range(1, 13))
day_category = list(range(1, 32))
weekday_cat = sorted(x_train.weekday.unique())
quarter_cat = [1, 2, 3, 4]
weekofyear_cat = sorted(x_train.weekofyear.unique())

# %%
encoder = OneHotEncoder(sparse=False,
                        categories=[weight_cat, year_category, month_category,
                                    day_category, weekday_cat, quarter_cat, weekofyear_cat],
                        handle_unknown='ignore')
x_train = encoder.fit_transform(x_train)
x_test = encoder.transform(x_test)
x_train.shape, x_test.shape
# Out:
# ((549, 1110), (61, 1110))

# %%
x_train = pd.DataFrame(x_train, columns=encoder.get_feature_names())
x_test = pd.DataFrame(x_test, columns=encoder.get_feature_names())
x_train.head(1)
# Out:
#     x0_1   x0_2   x0_3   x0_4   x0_5   x0_6   x0_7   x0_8   x0_9  x0_10  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x0_11  x0_12  x0_13  x0_14  x0_15  x0_16  x0_17  x0_18  x0_19  x0_20  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x0_21  x0_22  x0_23  x0_24  x0_25  x0_26  x0_27  x0_28  x0_29  x0_30  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x0_31  x0_32  x0_33  x0_34  x0_35  x0_36  x0_37  x0_38  x0_39  x0_40  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x0_41  x0_42  x0_43  x0_44  x0_45  x0_46  x0_47  x0_48  x0_49  x0_50  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x0_51  x0_52  x0_53  x0_54  x0_55  x0_56  x0_57  x0_58  x0_59  x0_60  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x0_61  x0_62  x0_63  x0_64  x0_65  x0_66  x0_67  x0_68  x0_69  x0_70  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x0_71  x0_72  x0_73  x0_74  x0_75  x0_76  x0_77  x0_78  x0_79  x0_80  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x0_81  x0_82  x0_83  x0_84  x0_85  x0_86  x0_87  x0_88  x0_89  x0_90  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x0_91  x0_92  x0_93  x0_94  x0_95  x0_96  x0_97  x0_98  x0_99  x0_100  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000  0.0000
#
#    x0_101  x0_102  x0_103  x0_104  x0_105  x0_106  x0_107  x0_108  x0_109  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_110  x0_111  x0_112  x0_113  x0_114  x0_115  x0_116  x0_117  x0_118  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_119  x0_120  x0_121  x0_122  x0_123  x0_124  x0_125  x0_126  x0_127  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_128  x0_129  x0_130  x0_131  x0_132  x0_133  x0_134  x0_135  x0_136  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_137  x0_138  x0_139  x0_140  x0_141  x0_142  x0_143  x0_144  x0_145  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_146  x0_147  x0_148  x0_149  x0_150  x0_151  x0_152  x0_153  x0_154  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_155  x0_156  x0_157  x0_158  x0_159  x0_160  x0_161  x0_162  x0_163  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_164  x0_165  x0_166  x0_167  x0_168  x0_169  x0_170  x0_171  x0_172  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_173  x0_174  x0_175  x0_176  x0_177  x0_178  x0_179  x0_180  x0_181  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_182  x0_183  x0_184  x0_185  x0_186  x0_187  x0_188  x0_189  x0_190  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_191  x0_192  x0_193  x0_194  x0_195  x0_196  x0_197  x0_198  x0_199  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_200  x0_201  x0_202  x0_203  x0_204  x0_205  x0_206  x0_207  x0_208  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_209  x0_210  x0_211  x0_212  x0_213  x0_214  x0_215  x0_216  x0_217  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_218  x0_219  x0_220  x0_221  x0_222  x0_223  x0_224  x0_225  x0_226  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_227  x0_228  x0_229  x0_230  x0_231  x0_232  x0_233  x0_234  x0_235  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_236  x0_237  x0_238  x0_239  x0_240  x0_241  x0_242  x0_243  x0_244  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_245  x0_246  x0_247  x0_248  x0_249  x0_250  x0_251  x0_252  x0_253  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_254  x0_255  x0_256  x0_257  x0_258  x0_259  x0_260  x0_261  x0_262  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_263  x0_264  x0_265  x0_266  x0_267  x0_268  x0_269  x0_270  x0_271  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_272  x0_273  x0_274  x0_275  x0_276  x0_277  x0_278  x0_279  x0_280  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_281  x0_282  x0_283  x0_284  x0_285  x0_286  x0_287  x0_288  x0_289  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_290  x0_291  x0_292  x0_293  x0_294  x0_295  x0_296  x0_297  x0_298  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_299  x0_300  x0_301  x0_302  x0_303  x0_304  x0_305  x0_306  x0_307  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_308  x0_309  x0_310  x0_311  x0_312  x0_313  x0_314  x0_315  x0_316  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_317  x0_318  x0_319  x0_320  x0_321  x0_322  x0_323  x0_324  x0_325  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_326  x0_327  x0_328  x0_329  x0_330  x0_331  x0_332  x0_333  x0_334  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_335  x0_336  x0_337  x0_338  x0_339  x0_340  x0_341  x0_342  x0_343  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_344  x0_345  x0_346  x0_347  x0_348  x0_349  x0_350  x0_351  x0_352  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_353  x0_354  x0_355  x0_356  x0_357  x0_358  x0_359  x0_360  x0_361  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_362  x0_363  x0_364  x0_365  x0_366  x0_367  x0_368  x0_369  x0_370  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_371  x0_372  x0_373  x0_374  x0_375  x0_376  x0_377  x0_378  x0_379  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_380  x0_381  x0_382  x0_383  x0_384  x0_385  x0_386  x0_387  x0_388  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_389  x0_390  x0_391  x0_392  x0_393  x0_394  x0_395  x0_396  x0_397  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_398  x0_399  x0_400  x0_401  x0_402  x0_403  x0_404  x0_405  x0_406  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_407  x0_408  x0_409  x0_410  x0_411  x0_412  x0_413  x0_414  x0_415  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_416  x0_417  x0_418  x0_419  x0_420  x0_421  x0_422  x0_423  x0_424  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_425  x0_426  x0_427  x0_428  x0_429  x0_430  x0_431  x0_432  x0_433  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_434  x0_435  x0_436  x0_437  x0_438  x0_439  x0_440  x0_441  x0_442  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_443  x0_444  x0_445  x0_446  x0_447  x0_448  x0_449  x0_450  x0_451  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_452  x0_453  x0_454  x0_455  x0_456  x0_457  x0_458  x0_459  x0_460  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_461  x0_462  x0_463  x0_464  x0_465  x0_466  x0_467  x0_468  x0_469  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_470  x0_471  x0_472  x0_473  x0_474  x0_475  x0_476  x0_477  x0_478  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_479  x0_480  x0_481  x0_482  x0_483  x0_484  x0_485  x0_486  x0_487  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_488  x0_489  x0_490  x0_491  x0_492  x0_493  x0_494  x0_495  x0_496  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_497  x0_498  x0_499  x0_500  x0_501  x0_502  x0_503  x0_504  x0_505  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_506  x0_507  x0_508  x0_509  x0_510  x0_511  x0_512  x0_513  x0_514  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_515  x0_516  x0_517  x0_518  x0_519  x0_520  x0_521  x0_522  x0_523  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  1.0000
#
#    x0_524  x0_525  x0_526  x0_527  x0_528  x0_529  x0_530  x0_531  x0_532  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_533  x0_534  x0_535  x0_536  x0_537  x0_538  x0_539  x0_540  x0_541  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_542  x0_543  x0_544  x0_545  x0_546  x0_547  x0_548  x0_549  x0_550  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_551  x0_552  x0_553  x0_554  x0_555  x0_556  x0_557  x0_558  x0_559  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_560  x0_561  x0_562  x0_563  x0_564  x0_565  x0_566  x0_567  x0_568  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_569  x0_570  x0_571  x0_572  x0_573  x0_574  x0_575  x0_576  x0_577  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_578  x0_579  x0_580  x0_581  x0_582  x0_583  x0_584  x0_585  x0_586  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_587  x0_588  x0_589  x0_590  x0_591  x0_592  x0_593  x0_594  x0_595  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_596  x0_597  x0_598  x0_599  x0_600  x0_601  x0_602  x0_603  x0_604  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_605  x0_606  x0_607  x0_608  x0_609  x0_610  x0_611  x0_612  x0_613  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_614  x0_615  x0_616  x0_617  x0_618  x0_619  x0_620  x0_621  x0_622  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_623  x0_624  x0_625  x0_626  x0_627  x0_628  x0_629  x0_630  x0_631  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_632  x0_633  x0_634  x0_635  x0_636  x0_637  x0_638  x0_639  x0_640  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_641  x0_642  x0_643  x0_644  x0_645  x0_646  x0_647  x0_648  x0_649  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_650  x0_651  x0_652  x0_653  x0_654  x0_655  x0_656  x0_657  x0_658  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_659  x0_660  x0_661  x0_662  x0_663  x0_664  x0_665  x0_666  x0_667  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_668  x0_669  x0_670  x0_671  x0_672  x0_673  x0_674  x0_675  x0_676  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_677  x0_678  x0_679  x0_680  x0_681  x0_682  x0_683  x0_684  x0_685  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_686  x0_687  x0_688  x0_689  x0_690  x0_691  x0_692  x0_693  x0_694  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_695  x0_696  x0_697  x0_698  x0_699  x0_700  x0_701  x0_702  x0_703  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_704  x0_705  x0_706  x0_707  x0_708  x0_709  x0_710  x0_711  x0_712  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_713  x0_714  x0_715  x0_716  x0_717  x0_718  x0_719  x0_720  x0_721  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_722  x0_723  x0_724  x0_725  x0_726  x0_727  x0_728  x0_729  x0_730  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_731  x0_732  x0_733  x0_734  x0_735  x0_736  x0_737  x0_738  x0_739  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_740  x0_741  x0_742  x0_743  x0_744  x0_745  x0_746  x0_747  x0_748  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_749  x0_750  x0_751  x0_752  x0_753  x0_754  x0_755  x0_756  x0_757  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_758  x0_759  x0_760  x0_761  x0_762  x0_763  x0_764  x0_765  x0_766  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_767  x0_768  x0_769  x0_770  x0_771  x0_772  x0_773  x0_774  x0_775  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_776  x0_777  x0_778  x0_779  x0_780  x0_781  x0_782  x0_783  x0_784  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_785  x0_786  x0_787  x0_788  x0_789  x0_790  x0_791  x0_792  x0_793  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_794  x0_795  x0_796  x0_797  x0_798  x0_799  x0_800  x0_801  x0_802  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_803  x0_804  x0_805  x0_806  x0_807  x0_808  x0_809  x0_810  x0_811  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_812  x0_813  x0_814  x0_815  x0_816  x0_817  x0_818  x0_819  x0_820  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_821  x0_822  x0_823  x0_824  x0_825  x0_826  x0_827  x0_828  x0_829  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_830  x0_831  x0_832  x0_833  x0_834  x0_835  x0_836  x0_837  x0_838  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_839  x0_840  x0_841  x0_842  x0_843  x0_844  x0_845  x0_846  x0_847  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_848  x0_849  x0_850  x0_851  x0_852  x0_853  x0_854  x0_855  x0_856  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_857  x0_858  x0_859  x0_860  x0_861  x0_862  x0_863  x0_864  x0_865  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_866  x0_867  x0_868  x0_869  x0_870  x0_871  x0_872  x0_873  x0_874  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_875  x0_876  x0_877  x0_878  x0_879  x0_880  x0_881  x0_882  x0_883  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_884  x0_885  x0_886  x0_887  x0_888  x0_889  x0_890  x0_891  x0_892  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_893  x0_894  x0_895  x0_896  x0_897  x0_898  x0_899  x0_900  x0_901  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_902  x0_903  x0_904  x0_905  x0_906  x0_907  x0_908  x0_909  x0_910  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_911  x0_912  x0_913  x0_914  x0_915  x0_916  x0_917  x0_918  x0_919  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_920  x0_921  x0_922  x0_923  x0_924  x0_925  x0_926  x0_927  x0_928  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_929  x0_930  x0_931  x0_932  x0_933  x0_934  x0_935  x0_936  x0_937  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_938  x0_939  x0_940  x0_941  x0_942  x0_943  x0_944  x0_945  x0_946  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_947  x0_948  x0_949  x0_950  x0_951  x0_952  x0_953  x0_954  x0_955  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_956  x0_957  x0_958  x0_959  x0_960  x0_961  x0_962  x0_963  x0_964  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_965  x0_966  x0_967  x0_968  x0_969  x0_970  x0_971  x0_972  x0_973  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_974  x0_975  x0_976  x0_977  x0_978  x0_979  x0_980  x0_981  x0_982  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_983  x0_984  x0_985  x0_986  x0_987  x0_988  x0_989  x0_990  x0_991  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#    x0_992  x0_993  x0_994  x0_995  x0_996  x0_997  x0_998  x0_999  x1_2019  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000   0.0000
#
#    x1_2020  x1_2021  x1_2022   x2_1   x2_2   x2_3   x2_4   x2_5   x2_6   x2_7  \
# 0   0.0000   1.0000   0.0000 0.0000 0.0000 0.0000 0.0000 1.0000 0.0000 0.0000
#
#     x2_8   x2_9  x2_10  x2_11  x2_12   x3_1   x3_2   x3_3   x3_4   x3_5  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#     x3_6   x3_7   x3_8   x3_9  x3_10  x3_11  x3_12  x3_13  x3_14  x3_15  \
# 0 0.0000 0.0000 1.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x3_16  x3_17  x3_18  x3_19  x3_20  x3_21  x3_22  x3_23  x3_24  x3_25  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x3_26  x3_27  x3_28  x3_29  x3_30  x3_31   x4_0   x4_1   x4_2   x4_3  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#     x4_4   x4_5   x4_6   x5_1   x5_2   x5_3   x5_4   x6_1   x6_2   x6_3  \
# 0 0.0000 1.0000 0.0000 0.0000 1.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#     x6_4   x6_5   x6_6   x6_7   x6_8   x6_9  x6_10  x6_11  x6_12  x6_13  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x6_14  x6_15  x6_16  x6_17  x6_18  x6_19  x6_20  x6_21  x6_22  x6_23  \
# 0 0.0000 0.0000 0.0000 0.0000 1.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x6_24  x6_25  x6_26  x6_27  x6_28  x6_29  x6_30  x6_31  x6_32  x6_33  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x6_34  x6_35  x6_36  x6_37  x6_38  x6_39  x6_40  x6_41  x6_42  x6_43  \
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#    x6_44  x6_45  x6_46  x6_47  x6_48  x6_49  x6_50  x6_51  x6_52  x6_53
# 0 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000

# %% [markdown]
# ## 训练

# %% [markdown]
# ### sklearn api

# %%
ts = time()
print(cross_val_score(xgbr, x_train, y_train, cv=5).mean())
time() - ts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-0d7f223be311> in <module>
#       1 ts = time()
# ----> 2 print(cross_val_score(xgbr, x_train, y_train, cv=5).mean())
#       3 time() - ts
#
# NameError: name 'xgbr' is not defined

# %%
xgbr = XGBRegressor(n_estimators=200,
                    learning_rate=0.35,
                    max_depth=7,
                    subsample=0.6,
                    colsample_bytree=0.7,
                    objective='reg:squarederror',
                    base_score=0.5,
                    gamma=1,
                    n_jobs=8, verbosity=1)

xgbr.fit(x_train, y_train, eval_set=[(x_train, y_train), (x_test, y_test)],
         early_stopping_rounds=20, verbose=True)
# Out:
# [0]	validation_0-rmse:91.29481	validation_1-rmse:116.22157
# [1]	validation_0-rmse:72.20888	validation_1-rmse:93.28026
# [2]	validation_0-rmse:57.94956	validation_1-rmse:79.61459
# [3]	validation_0-rmse:48.64489	validation_1-rmse:72.97636
# [4]	validation_0-rmse:41.64614	validation_1-rmse:69.67192
# [5]	validation_0-rmse:37.65411	validation_1-rmse:65.27844
# [6]	validation_0-rmse:36.05523	validation_1-rmse:63.82892
# [7]	validation_0-rmse:34.23924	validation_1-rmse:61.24684
# [8]	validation_0-rmse:32.47018	validation_1-rmse:61.56541
# [9]	validation_0-rmse:30.04701	validation_1-rmse:59.53272
# [10]	validation_0-rmse:28.15577	validation_1-rmse:58.47178
# [11]	validation_0-rmse:26.94684	validation_1-rmse:59.48925
# [12]	validation_0-rmse:25.39842	validation_1-rmse:57.90744
# [13]	validation_0-rmse:23.61903	validation_1-rmse:57.33630
# [14]	validation_0-rmse:22.80758	validation_1-rmse:57.10327
# [15]	validation_0-rmse:22.12356	validation_1-rmse:56.20204
# [16]	validation_0-rmse:21.73964	validation_1-rmse:56.17963
# [17]	validation_0-rmse:21.24145	validation_1-rmse:56.29812
# [18]	validation_0-rmse:20.52147	validation_1-rmse:56.50656
# [19]	validation_0-rmse:19.99382	validation_1-rmse:56.45279
# [20]	validation_0-rmse:19.26339	validation_1-rmse:57.15942
# [21]	validation_0-rmse:18.30031	validation_1-rmse:57.39990
# [22]	validation_0-rmse:17.81983	validation_1-rmse:57.42034
# [23]	validation_0-rmse:17.53893	validation_1-rmse:57.41769
# [24]	validation_0-rmse:17.10769	validation_1-rmse:57.17890
# [25]	validation_0-rmse:16.79033	validation_1-rmse:57.73666
# [26]	validation_0-rmse:16.49442	validation_1-rmse:57.10172
# [27]	validation_0-rmse:16.18272	validation_1-rmse:57.01963
# [28]	validation_0-rmse:15.94876	validation_1-rmse:56.35426
# [29]	validation_0-rmse:15.71223	validation_1-rmse:56.36557
# [30]	validation_0-rmse:15.48780	validation_1-rmse:56.60479
# [31]	validation_0-rmse:15.19500	validation_1-rmse:56.62182
# [32]	validation_0-rmse:14.81975	validation_1-rmse:56.15388
# [33]	validation_0-rmse:14.57028	validation_1-rmse:56.26061
# [34]	validation_0-rmse:14.39435	validation_1-rmse:56.26593
# [35]	validation_0-rmse:14.22867	validation_1-rmse:56.45721
# [36]	validation_0-rmse:13.80110	validation_1-rmse:56.65954
# [37]	validation_0-rmse:13.63728	validation_1-rmse:56.65584
# [38]	validation_0-rmse:13.59459	validation_1-rmse:56.72993
# [39]	validation_0-rmse:13.30162	validation_1-rmse:56.61625
# [40]	validation_0-rmse:13.03668	validation_1-rmse:56.89745
# [41]	validation_0-rmse:12.76880	validation_1-rmse:56.89026
# [42]	validation_0-rmse:12.53935	validation_1-rmse:56.85723
# [43]	validation_0-rmse:12.30063	validation_1-rmse:56.70101
# [44]	validation_0-rmse:11.97907	validation_1-rmse:57.07487
# [45]	validation_0-rmse:11.89330	validation_1-rmse:56.77566
# [46]	validation_0-rmse:11.68306	validation_1-rmse:56.58354
# [47]	validation_0-rmse:11.50281	validation_1-rmse:56.59822
# [48]	validation_0-rmse:11.42288	validation_1-rmse:56.37413
# [49]	validation_0-rmse:11.30344	validation_1-rmse:56.30923
# [50]	validation_0-rmse:11.09543	validation_1-rmse:56.66010
# [51]	validation_0-rmse:10.93641	validation_1-rmse:56.61663
# [52]	validation_0-rmse:10.68061	validation_1-rmse:56.14431
# [53]	validation_0-rmse:10.55544	validation_1-rmse:56.26841
# [54]	validation_0-rmse:10.34302	validation_1-rmse:56.26722
# [55]	validation_0-rmse:10.11056	validation_1-rmse:56.87418
# [56]	validation_0-rmse:9.96635	validation_1-rmse:57.04091
# [57]	validation_0-rmse:9.86796	validation_1-rmse:57.08922
# [58]	validation_0-rmse:9.73099	validation_1-rmse:57.02727
# [59]	validation_0-rmse:9.62974	validation_1-rmse:57.34316
# [60]	validation_0-rmse:9.48124	validation_1-rmse:57.24412
# [61]	validation_0-rmse:9.32784	validation_1-rmse:57.50184
# [62]	validation_0-rmse:9.23356	validation_1-rmse:57.47440
# [63]	validation_0-rmse:9.11873	validation_1-rmse:57.41392
# [64]	validation_0-rmse:9.02888	validation_1-rmse:57.41005
# [65]	validation_0-rmse:8.95551	validation_1-rmse:57.43263
# [66]	validation_0-rmse:8.84143	validation_1-rmse:57.06594
# [67]	validation_0-rmse:8.79862	validation_1-rmse:57.10331
# [68]	validation_0-rmse:8.66822	validation_1-rmse:57.10329
# [69]	validation_0-rmse:8.56016	validation_1-rmse:57.09600
# [70]	validation_0-rmse:8.35051	validation_1-rmse:57.14799
# [71]	validation_0-rmse:8.23365	validation_1-rmse:57.14545
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=1, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.35, max_delta_step=0, max_depth=7,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=200, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=0.6,
#              tree_method='exact', validate_parameters=1, verbosity=1)

# %%
# 网格搜索
# params_grid = {'learning_rate': np.arange(0, 1, 0.05)}

# params_grid = {'max_depth': range(0, 8, 1)}

# params_grid = {'subsample': np.arange(0, 1, 0.05)}
params_grid = {'colsample_bytree': np.arange(0, 1, 0.05)}

gridCV = GridSearchCV(xgbr, params_grid, cv=5, scoring='r2', n_jobs=8)

ts = time()
gridCV.fit(x_train, y_train)
print(time() - ts)
gridCV.best_params_, gridCV.best_score_

# %%
result = xgbr.evals_result()
plt.plot(result['validation_0']['rmse'])
plt.plot(result['validation_1']['rmse'])

# %% [markdown]
# ### xgboost api

# %%
dtrain = xgb.DMatrix(x_train, y_train)
dtest = xgb.DMatrix(x_test, y_test)

params = {'eta': 0.3,
          'objective': 'reg:squarederror',
          'gamma': 0,
          'max_depth': 5,
          'subsample': 0.5,
          'colsample_bytree': 1,
          'base_score': 0.5,
          'n_jobs': 8}

a = {}  # 记录验证集结果
model = xgb.train(params, dtrain, 300, early_stopping_rounds=20, evals=[
                  (dtest, 'test')], evals_result=a, verbose_eval=True)
# Out:
# [0]	test-rmse:787.05859
# [1]	test-rmse:605.59271
# [2]	test-rmse:535.71790
# [3]	test-rmse:504.41638
# [4]	test-rmse:451.57785
# [5]	test-rmse:416.67691
# [6]	test-rmse:368.91260
# [7]	test-rmse:337.75443
# [8]	test-rmse:336.24973
# [9]	test-rmse:334.07410
# [10]	test-rmse:320.31738
# [11]	test-rmse:320.45258
# [12]	test-rmse:305.20642
# [13]	test-rmse:285.16476
# [14]	test-rmse:286.65512
# [15]	test-rmse:284.19476
# [16]	test-rmse:284.05826
# [17]	test-rmse:283.70371
# [18]	test-rmse:279.53226
# [19]	test-rmse:281.19687
# [20]	test-rmse:277.47406
# [21]	test-rmse:278.99527
# [22]	test-rmse:273.31439
# [23]	test-rmse:263.51685
# [24]	test-rmse:261.43713
# [25]	test-rmse:255.99350
# [26]	test-rmse:256.36807
# [27]	test-rmse:255.47286
# [28]	test-rmse:254.09540
# [29]	test-rmse:256.87180
# [30]	test-rmse:258.02121
# [31]	test-rmse:252.14825
# [32]	test-rmse:259.23050
# [33]	test-rmse:261.94702
# [34]	test-rmse:259.51361
# [35]	test-rmse:260.83997
# [36]	test-rmse:257.71121
# [37]	test-rmse:259.52267
# [38]	test-rmse:266.07889
# [39]	test-rmse:259.49432
# [40]	test-rmse:259.80453
# [41]	test-rmse:260.76218
# [42]	test-rmse:260.21356
# [43]	test-rmse:252.00769
# [44]	test-rmse:250.13261
# [45]	test-rmse:252.78278
# [46]	test-rmse:250.78601
# [47]	test-rmse:253.06047
# [48]	test-rmse:252.72423
# [49]	test-rmse:254.15414
# [50]	test-rmse:254.56889
# [51]	test-rmse:257.14062
# [52]	test-rmse:255.93312
# [53]	test-rmse:254.03284
# [54]	test-rmse:252.11551
# [55]	test-rmse:250.71370
# [56]	test-rmse:249.98627
# [57]	test-rmse:249.21081
# [58]	test-rmse:249.09166
# [59]	test-rmse:249.54633
# [60]	test-rmse:249.08185
# [61]	test-rmse:247.98508
# [62]	test-rmse:246.80408
# [63]	test-rmse:248.27844
# [64]	test-rmse:247.30556
# [65]	test-rmse:246.65703
# [66]	test-rmse:244.42323
# [67]	test-rmse:241.21217
# [68]	test-rmse:238.19881
# [69]	test-rmse:242.58142
# [70]	test-rmse:244.56546
# [71]	test-rmse:244.74786
# [72]	test-rmse:246.17410
# [73]	test-rmse:246.11646
# [74]	test-rmse:247.32744
# [75]	test-rmse:246.04793
# [76]	test-rmse:243.21490
# [77]	test-rmse:243.78812
# [78]	test-rmse:247.25171
# [79]	test-rmse:251.47815
# [80]	test-rmse:252.76279
# [81]	test-rmse:251.71710
# [82]	test-rmse:251.40764
# [83]	test-rmse:252.60289
# [84]	test-rmse:251.46544
# [85]	test-rmse:252.78674
# [86]	test-rmse:253.49190
# [87]	test-rmse:251.10969

# %% [markdown]
# ## 测试

# %% [markdown]
# ### sklearn api

# %%
y_pred = xgbr.predict(x_test)
print('metrics1: {:.3f}\nmetrics2: {:.3f}\nr2: {:.3f}'.format(metrics1(y_test, y_pred),
                                                              metrics2(
                                                                  y_test, y_pred),
                                                              r2_score(y_test, y_pred)))
# Out:
# metrics1: 0.987
# metrics2: -0.034
# r2: 0.740

# %%
plt.figure(figsize=(15, 4))
plt.plot(y_test.values, label='true')
plt.plot(y_pred, label='predict')
plt.xticks(rotation=90)
plt.grid()
plt.legend(fontsize=15)

# %%
a = xgbr.get_booster().get_score(importance_type='gain')
# len(a)
sorted(a.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('x6_51', 57550.03545738462),
#  ('x2_12', 33535.52279131249),
#  ('x0_317', 28840.72957630769),
#  ('x0_394', 27196.3125),
#  ('x0_364', 19281.603190058817),
#  ('x6_50', 18164.34922526154),
#  ('x6_49', 17047.99481),
#  ('x0_366', 16330.354646666667),
#  ('x0_368', 15625.864258),
#  ('x0_392', 15596.2960665),
#  ('x2_5', 13098.1095535),
#  ('x0_395', 12970.7559355),
#  ('x6_27', 11978.52979925),
#  ('x0_369', 11519.547344499999),
#  ('x1_2019', 11337.003072231875),
#  ('x6_40', 11136.1875),
#  ('x1_2021', 10496.735829473077),
#  ('x2_1', 8611.159353000001),
#  ('x2_11', 8572.554775485714),
#  ('x3_20', 6868.77169585),
#  ('x6_45', 5731.8494875),
#  ('x0_370', 4741.171287454545),
#  ('x6_48', 4449.624376111111),
#  ('x0_3', 4224.637596142858),
#  ('x0_385', 4224.14493125),
#  ('x6_44', 4187.2996496666665),
#  ('x2_9', 4157.407201666666),
#  ('x6_19', 4016.633325),
#  ('x2_8', 3636.5604492666666),
#  ('x2_7', 3608.376940855556),
#  ('x0_34', 3582.4575056000003),
#  ('x0_517', 3284.42433),
#  ('x6_18', 3245.8186780000005),
#  ('x5_3', 3233.2013354),
#  ('x0_212', 3040.111108714286),
#  ('x6_42', 3036.7137422499995),
#  ('x6_29', 2939.8770776666665),
#  ('x4_6', 2929.906363381818),
#  ('x3_2', 2861.311371961539),
#  ('x0_380', 2704.5639675),
#  ('x0_240', 2647.57227),
#  ('x3_5', 2479.690521281667),
#  ('x6_31', 2457.6682299999998),
#  ('x6_43', 2419.1850875),
#  ('x1_2020', 2367.2489234496875),
#  ('x6_2', 2237.9965570000004),
#  ('x3_24', 2235.783581272857),
#  ('x0_230', 2175.8032647),
#  ('x2_6', 2064.7164805333337),
#  ('x6_3', 1979.542452),
#  ('x5_4', 1939.60321004),
#  ('x6_13', 1857.558395),
#  ('x3_25', 1835.5400298333334),
#  ('x6_14', 1807.8886485750002),
#  ('x0_386', 1794.5359578750001),
#  ('x0_568', 1651.3137712857144),
#  ('x0_424', 1600.95215),
#  ('x6_30', 1538.7510653333331),
#  ('x3_19', 1495.6386733333331),
#  ('x0_234', 1456.2821),
#  ('x0_6', 1443.89233),
#  ('x0_213', 1417.979),
#  ('x0_376', 1409.8872104285715),
#  ('x3_14', 1388.7278919333332),
#  ('x4_2', 1306.5024178222222),
#  ('x0_60', 1288.579984),
#  ('x0_236', 1272.5562907),
#  ('x5_2', 1270.6066844285713),
#  ('x6_4', 1262.7195646666667),
#  ('x0_367', 1197.0575006666666),
#  ('x0_21', 1150.1306155),
#  ('x0_328', 1086.27734),
#  ('x3_31', 1073.580853),
#  ('x0_106', 1070.53223),
#  ('x0_242', 1053.5248115),
#  ('x2_10', 1041.7087565),
#  ('x4_4', 1038.1197677266669),
#  ('x0_2', 983.3700212499999),
#  ('x3_30', 920.6544903833334),
#  ('x0_359', 916.8127020000001),
#  ('x3_11', 913.70503225),
#  ('x6_52', 900.3728521250002),
#  ('x0_382', 882.385969925),
#  ('x4_0', 876.3340700923077),
#  ('x5_1', 876.0029121857144),
#  ('x0_35', 874.5831289999999),
#  ('x0_379', 817.5051905),
#  ('x0_432', 817.18512),
#  ('x0_43', 815.5523469999999),
#  ('x6_15', 809.8251533333333),
#  ('x4_3', 803.5137026875),
#  ('x0_363', 796.0925192000001),
#  ('x0_157', 791.6473835),
#  ('x6_9', 782.2131475),
#  ('x6_41', 778.9819832000001),
#  ('x3_12', 745.8380455),
#  ('x4_5', 731.7467801124999),
#  ('x0_224', 727.2161575),
#  ('x3_22', 726.4933783),
#  ('x0_384', 725.457687625),
#  ('x6_12', 716.1121205000001),
#  ('x0_90', 709.330734),
#  ('x0_36', 702.0998372500001),
#  ('x6_6', 675.220337),
#  ('x0_323', 672.6593429999999),
#  ('x0_409', 664.7178353333334),
#  ('x6_17', 633.8302981999999),
#  ('x0_358', 630.1218662666666),
#  ('x0_89', 627.4585063333334),
#  ('x0_244', 625.8163453333333),
#  ('x0_9', 622.3855265000001),
#  ('x0_72', 621.1616096),
#  ('x3_29', 610.438202),
#  ('x3_18', 606.4230000000001),
#  ('x6_5', 578.783683),
#  ('x2_2', 574.4917912714286),
#  ('x0_228', 570.978149),
#  ('x6_1', 553.50855725),
#  ('x6_8', 549.82782),
#  ('x0_160', 541.3233172500001),
#  ('x0_28', 540.6412125),
#  ('x0_248', 540.3879577999999),
#  ('x0_110', 535.751785),
#  ('x0_133', 530.4264525),
#  ('x0_37', 528.81244675),
#  ('x0_125', 524.097778),
#  ('x0_391', 519.6777345),
#  ('x0_24', 518.4467916666667),
#  ('x0_321', 516.93475345),
#  ('x3_13', 514.78493495),
#  ('x0_135', 506.60015899999996),
#  ('x0_69', 505.785522),
#  ('x0_388', 501.3103306833334),
#  ('x0_241', 497.315796),
#  ('x0_383', 495.7492985),
#  ('x0_159', 490.8905985),
#  ('x0_91', 482.446426),
#  ('x0_13', 476.8125),
#  ('x0_420', 471.5823873333334),
#  ('x0_111', 471.5040055),
#  ('x6_53', 444.9974485999999),
#  ('x0_195', 442.708252),
#  ('x4_1', 424.73450150166667),
#  ('x0_146', 421.9832579999999),
#  ('x3_21', 417.378348),
#  ('x0_156', 413.25),
#  ('x3_8', 413.15124),
#  ('x2_3', 409.9125675),
#  ('x6_16', 407.646393),
#  ('x0_17', 406.666382),
#  ('x0_360', 403.444946),
#  ('x0_142', 399.89454319999993),
#  ('x0_239', 399.731323),
#  ('x0_326', 397.077271),
#  ('x0_314', 392.950317),
#  ('x0_186', 389.50167799999997),
#  ('x0_65', 384.63487250000003),
#  ('x0_357', 376.6267272),
#  ('x6_20', 376.60914625000004),
#  ('x0_431', 375.179047),
#  ('x0_10', 374.198975),
#  ('x0_144', 357.533203),
#  ('x0_161', 355.118408),
#  ('x6_21', 354.40625),
#  ('x0_405', 353.47015375),
#  ('x0_15', 352.926056),
#  ('x0_16', 352.52844200000004),
#  ('x3_4', 352.36108952999996),
#  ('x0_61', 350.32214350000004),
#  ('x3_27', 342.59731674999995),
#  ('x0_308', 341.88435350000003),
#  ('x0_389', 341.6214295),
#  ('x0_411', 341.61203),
#  ('x0_49', 338.404541),
#  ('x0_22', 334.0443115),
#  ('x0_39', 331.7957152),
#  ('x6_10', 330.61703124999997),
#  ('x2_4', 327.55823167399996),
#  ('x0_390', 326.52262875),
#  ('x0_153', 322.928772),
#  ('x3_17', 320.16739665),
#  ('x0_184', 317.002014),
#  ('x0_175', 316.578735),
#  ('x0_149', 314.372314),
#  ('x0_430', 305.98150599999997),
#  ('x3_15', 304.813289625),
#  ('x3_7', 304.37565272500007),
#  ('x0_547', 295.546875),
#  ('x0_610', 294.468821),
#  ('x0_611', 291.31744365000003),
#  ('x0_418', 291.039421),
#  ('x6_35', 290.9327545),
#  ('x3_10', 289.7529321525),
#  ('x0_275', 287.1425325),
#  ('x6_28', 284.053101),
#  ('x0_67', 283.732056),
#  ('x0_402', 282.2924045),
#  ('x0_378', 281.233887),
#  ('x0_226', 280.7059635),
#  ('x0_480', 280.19519),
#  ('x3_28', 277.25519565),
#  ('x0_77', 275.160767),
#  ('x0_165', 274.90625),
#  ('x0_27', 273.0870463333333),
#  ('x0_140', 264.144958),
#  ('x0_238', 264.0142773333333),
#  ('x3_1', 262.520081),
#  ('x0_128', 257.574219),
#  ('x0_79', 257.507248),
#  ('x0_26', 257.4859823333333),
#  ('x0_215', 254.329712),
#  ('x0_51', 250.437927),
#  ('x0_117', 250.040771),
#  ('x0_503', 246.91452),
#  ('x0_103', 239.534912),
#  ('x0_235', 238.413025),
#  ('x0_203', 237.9303998),
#  ('x0_311', 236.00036640000002),
#  ('x0_118', 226.640259),
#  ('x0_196', 225.903198),
#  ('x0_29', 223.381226),
#  ('x0_148', 220.60406115),
#  ('x0_519', 218.960449),
#  ('x0_362', 216.56079850000003),
#  ('x0_515', 216.287964),
#  ('x0_374', 213.350136),
#  ('x0_263', 212.38623),
#  ('x0_457', 210.772217),
#  ('x0_232', 210.15545633333332),
#  ('x0_286', 209.115723),
#  ('x0_522', 208.95459),
#  ('x3_3', 208.18747823333334),
#  ('x0_7', 207.4726562),
#  ('x0_604', 207.464966),
#  ('x0_613', 207.25087),
#  ('x6_24', 206.924011),
#  ('x0_88', 205.94016249999999),
#  ('x0_348', 204.737305),
#  ('x0_421', 204.46936),
#  ('x0_145', 201.361481),
#  ('x0_211', 196.34020249999998),
#  ('x0_255', 180.839371),
#  ('x0_355', 177.241241),
#  ('x6_25', 176.06042493333334),
#  ('x0_183', 174.897766),
#  ('x0_416', 172.8125),
#  ('x0_86', 170.753113),
#  ('x0_19', 170.6065065),
#  ('x0_113', 167.946808),
#  ('x6_36', 166.587402),
#  ('x0_202', 166.53436299999998),
#  ('x0_42', 165.788086),
#  ('x0_208', 162.630188),
#  ('x0_351', 162.443604),
#  ('x0_518', 162.2360304),
#  ('x6_34', 161.656769),
#  ('x0_523', 160.23226306666666),
#  ('x0_120', 155.17627),
#  ('x0_486', 151.85970275),
#  ('x0_302', 151.774902),
#  ('x0_307', 150.6134645),
#  ('x3_6', 148.03613265),
#  ('x0_96', 146.014572),
#  ('x0_356', 143.371246),
#  ('x0_279', 143.124329),
#  ('x0_460', 141.85434),
#  ('x0_163', 138.938812),
#  ('x0_442', 137.337891),
#  ('x0_428', 137.21869893333334),
#  ('x0_95', 128.534118805),
#  ('x0_579', 124.134094),
#  ('x0_4', 122.882813),
#  ('x0_23', 120.308128),
#  ('x0_200', 117.82067889999999),
#  ('x0_32', 117.74305),
#  ('x0_587', 117.351135),
#  ('x0_581', 116.840149),
#  ('x0_162', 116.3093719),
#  ('x0_20', 116.0),
#  ('x0_305', 113.946655),
#  ('x0_303', 111.4004518),
#  ('x0_12', 111.255371),
#  ('x0_309', 111.24386584999999),
#  ('x0_339', 108.555984),
#  ('x0_319', 100.45996103333333),
#  ('x0_257', 98.0969999),
#  ('x0_18', 96.59652725000001),
#  ('x0_31', 96.02688584999999),
#  ('x0_496', 91.8560181),
#  ('x0_267', 91.6972656),
#  ('x0_563', 91.3206177),
#  ('x0_603', 88.1646729),
#  ('x0_511', 87.26211619),
#  ('x0_353', 86.7285156),
#  ('x0_334', 83.10568225),
#  ('x0_537', 77.5911255),
#  ('x0_513', 77.0584566),
#  ('x0_336', 72.6505281),
#  ('x0_201', 70.4767419),
#  ('x0_495', 70.4527435),
#  ('x0_287', 68.7867126),
#  ('x0_467', 68.3644409),
#  ('x0_476', 66.4820557),
#  ('x6_26', 66.3916992),
#  ('x0_152', 63.5942269),
#  ('x0_164', 63.1420631),
#  ('x0_456', 62.7617188),
#  ('x0_112', 59.2871094),
#  ('x0_25', 59.1419678),
#  ('x0_375', 53.7197266),
#  ('x0_41', 52.8378487),
#  ('x0_510', 51.6807938),
#  ('x0_535', 51.458374),
#  ('x0_87', 49.89054255),
#  ('x0_124', 48.567749),
#  ('x0_450', 48.195770249999995),
#  ('x0_315', 46.5684814),
#  ('x0_502', 46.4525986),
#  ('x0_533', 46.3648071),
#  ('x0_614', 45.1876984),
#  ('x0_548', 44.6841278),
#  ('x0_444', 43.2062378),
#  ('x0_554', 43.1311035),
#  ('x0_341', 40.049593915),
#  ('x0_5', 39.875),
#  ('x0_84', 39.5894165),
#  ('x3_23', 39.57270049666666),
#  ('x0_85', 37.3444824),
#  ('x0_527', 35.9355354),
#  ('x0_132', 35.7618408),
#  ('x0_344', 34.5748901),
#  ('x0_595', 30.1550293),
#  ('x0_584', 28.3614807),
#  ('x0_401', 27.9045582),
#  ('x0_499', 26.9883251),
#  ('x0_190', 25.59602354333333),
#  ('x0_562', 25.3386345),
#  ('x0_11', 24.5573444),
#  ('x0_30', 24.2312622),
#  ('x0_92', 19.6519547),
#  ('x0_372', 17.6254272),
#  ('x0_273', 13.928894),
#  ('x0_436', 12.5521374),
#  ('x0_468', 12.5333862),
#  ('x0_33', 12.4165649),
#  ('x0_583', 12.07168199),
#  ('x0_552', 11.49952315),
#  ('x0_491', 10.8031788),
#  ('x0_482', 10.7745972),
#  ('x0_530', 10.5413952),
#  ('x0_447', 8.63079834),
#  ('x0_192', 8.43984985),
#  ('x0_266', 8.09664536),
#  ('x0_138', 6.65640306),
#  ('x0_276', 6.16742039),
#  ('x0_127', 4.54870605),
#  ('x0_62', 3.98361206),
#  ('x0_50', 2.46933937),
#  ('x0_617', 1.46417594)]

# %%
['f'+str(i) for i in list(range(1100))][999:-1]
# Out:
# ['f999',
#  'f1000',
#  'f1001',
#  'f1002',
#  'f1003',
#  'f1004',
#  'f1005',
#  'f1006',
#  'f1007',
#  'f1008',
#  'f1009',
#  'f1010',
#  'f1011',
#  'f1012',
#  'f1013',
#  'f1014',
#  'f1015',
#  'f1016',
#  'f1017',
#  'f1018',
#  'f1019',
#  'f1020',
#  'f1021',
#  'f1022',
#  'f1023',
#  'f1024',
#  'f1025',
#  'f1026',
#  'f1027',
#  'f1028',
#  'f1029',
#  'f1030',
#  'f1031',
#  'f1032',
#  'f1033',
#  'f1034',
#  'f1035',
#  'f1036',
#  'f1037',
#  'f1038',
#  'f1039',
#  'f1040',
#  'f1041',
#  'f1042',
#  'f1043',
#  'f1044',
#  'f1045',
#  'f1046',
#  'f1047',
#  'f1048',
#  'f1049',
#  'f1050',
#  'f1051',
#  'f1052',
#  'f1053',
#  'f1054',
#  'f1055',
#  'f1056',
#  'f1057',
#  'f1058',
#  'f1059',
#  'f1060',
#  'f1061',
#  'f1062',
#  'f1063',
#  'f1064',
#  'f1065',
#  'f1066',
#  'f1067',
#  'f1068',
#  'f1069',
#  'f1070',
#  'f1071',
#  'f1072',
#  'f1073',
#  'f1074',
#  'f1075',
#  'f1076',
#  'f1077',
#  'f1078',
#  'f1079',
#  'f1080',
#  'f1081',
#  'f1082',
#  'f1083',
#  'f1084',
#  'f1085',
#  'f1086',
#  'f1087',
#  'f1088',
#  'f1089',
#  'f1090',
#  'f1091',
#  'f1092',
#  'f1093',
#  'f1094',
#  'f1095',
#  'f1096',
#  'f1097',
#  'f1098']

# %%
zipp = zip(['f'+str(i) for i in list(range(1200))], encoder.get_feature_names())

# %%
cc = dict(list(zipp))

# %%
for i in zipp:
    print(i)

# %%
cc['f110']
# Out:
# 'x0_111'

# %%
bb
# Out:
# [('f1000', 30),
#  ('f1049', 14),
#  ('f1107', 13),
#  ('f566', 12),
#  ('f1052', 11),
#  ('f363', 10),
#  ('f1048', 10),
#  ('f1050', 10),
#  ('f1106', 9),
#  ('f519', 9),
#  ('f360', 9),
#  ('f1047', 9),
#  ('f520', 9),
#  ('f1007', 9),
#  ('f1090', 8),
#  ('f999', 8),
#  ('f1014', 7),
#  ('f1038', 7),
#  ('f381', 7),
#  ('f1057', 7),
#  ('f1051', 7),
#  ('f1031', 7),
#  ('f23', 7),
#  ('f1105', 6),
#  ('f1005', 6),
#  ('f1097', 6),
#  ('f1081', 6),
#  ('f1011', 6),
#  ('f388', 6),
#  ('f1025', 6),
#  ('f1023', 6),
#  ('f1030', 6),
#  ('f1104', 6),
#  ('f1029', 6),
#  ('f1053', 6),
#  ('f19', 6),
#  ('f1001', 6),
#  ('f1100', 6),
#  ('f366', 6),
#  ('f377', 6),
#  ('f383', 5),
#  ('f1056', 5),
#  ('f1095', 5),
#  ('f1022', 5),
#  ('f1036', 5),
#  ('f378', 5),
#  ('f27', 5),
#  ('f382', 5),
#  ('f1039', 5),
#  ('f380', 5),
#  ('f1054', 5),
#  ('f395', 5),
#  ('f1040', 5),
#  ('f1003', 5),
#  ('f231', 5),
#  ('f1108', 4),
#  ('f256', 4),
#  ('f1020', 4),
#  ('f1008', 4),
#  ('f1055', 4),
#  ('f43', 4),
#  ('f327', 4),
#  ('f371', 4),
#  ('f1028', 4),
#  ('f1024', 4),
#  ('f1013', 4),
#  ('f1062', 4),
#  ('f5', 4),
#  ('f1037', 4),
#  ('f1010', 4),
#  ('f1099', 4),
#  ('f1096', 3),
#  ('f1089', 3),
#  ('f1069', 3),
#  ('f1033', 3),
#  ('f572', 3),
#  ('f1070', 3),
#  ('f312', 3),
#  ('f1035', 3),
#  ('f1067', 3),
#  ('f1094', 3),
#  ('f1015', 3),
#  ('f394', 3),
#  ('f1074', 3),
#  ('f196', 3),
#  ('f6', 3),
#  ('f1046', 3),
#  ('f1016', 3),
#  ('f1034', 3),
#  ('f17', 3),
#  ('f18', 3),
#  ('f499', 3),
#  ('f379', 3),
#  ('f257', 3),
#  ('f1019', 3),
#  ('f1077', 3),
#  ('f1017', 3),
#  ('f628', 3),
#  ('f1084', 3),
#  ('f361', 3),
#  ('f325', 3),
#  ('f168', 3),
#  ('f1073', 3),
#  ('f13', 3),
#  ('f1086', 3),
#  ('f1018', 3),
#  ('f1032', 3),
#  ('f24', 3),
#  ('f307', 2),
#  ('f469', 2),
#  ('f386', 2),
#  ('f1109', 2),
#  ('f365', 2),
#  ('f267', 2),
#  ('f286', 2),
#  ('f2', 2),
#  ('f390', 2),
#  ('f9', 2),
#  ('f3', 2),
#  ('f301', 2),
#  ('f1078', 2),
#  ('f1027', 2),
#  ('f74', 2),
#  ('f1072', 2),
#  ('f376', 2),
#  ('f220', 2),
#  ('f339', 2),
#  ('f1102', 2),
#  ('f567', 2),
#  ('f200', 2),
#  ('f362', 2),
#  ('f88', 2),
#  ('f66', 2),
#  ('f464', 2),
#  ('f356', 2),
#  ('f1088', 2),
#  ('f1085', 2),
#  ('f596', 2),
#  ('f82', 2),
#  ('f156', 2),
#  ('f516', 2),
#  ('f306', 2),
#  ('f627', 2),
#  ('f333', 2),
#  ('f1064', 2),
#  ('f358', 2),
#  ('f1045', 2),
#  ('f1026', 2),
#  ('f587', 2),
#  ('f1066', 2),
#  ('f535', 2),
#  ('f536', 2),
#  ('f348', 2),
#  ('f521', 2),
#  ('f322', 2),
#  ('f173', 2),
#  ('f1006', 2),
#  ('f1083', 2),
#  ('f316', 2),
#  ('f465', 2),
#  ('f540', 2),
#  ('f478', 2),
#  ('f589', 2),
#  ('f73', 2),
#  ('f354', 2),
#  ('f115', 1),
#  ('f197', 1),
#  ('f309', 1),
#  ('f1101', 1),
#  ('f28', 1),
#  ('f387', 1),
#  ('f1091', 1),
#  ('f110', 1),
#  ('f113', 1),
#  ('f391', 1),
#  ('f20', 1),
#  ('f373', 1),
#  ('f75', 1),
#  ('f285', 1),
#  ('f12', 1),
#  ('f45', 1),
#  ('f517', 1),
#  ('f146', 1),
#  ('f529', 1),
#  ('f15', 1),
#  ('f109', 1),
#  ('f446', 1),
#  ('f370', 1),
#  ('f7', 1),
#  ('f372', 1),
#  ('f258', 1),
#  ('f1044', 1),
#  ('f192', 1),
#  ('f330', 1),
#  ('f503', 1),
#  ('f132', 1),
#  ('f364', 1),
#  ('f311', 1),
#  ('f305', 1),
#  ('f0', 1),
#  ('f500', 1),
#  ('f1065', 1),
#  ('f304', 1),
#  ('f562', 1),
#  ('f442', 1),
#  ('f260', 1),
#  ('f33', 1),
#  ('f337', 1),
#  ('f340', 1),
#  ('f287', 1),
#  ('f560', 1),
#  ('f166', 1),
#  ('f8', 1),
#  ('f283', 1),
#  ('f357', 1),
#  ('f142', 1),
#  ('f180', 1),
#  ('f167', 1),
#  ('f1021', 1),
#  ('f140', 1),
#  ('f1058', 1),
#  ('f404', 1),
#  ('f253', 1),
#  ('f261', 1),
#  ('f262', 1),
#  ('f1087', 1),
#  ('f623', 1),
#  ('f625', 1),
#  ('f612', 1),
#  ('f608', 1),
#  ('f569', 1),
#  ('f226', 1),
#  ('f203', 1),
#  ('f598', 1),
#  ('f11', 1),
#  ('f1071', 1),
#  ('f264', 1),
#  ('f128', 1),
#  ('f497', 1),
#  ('f310', 1),
#  ('f447', 1),
#  ('f78', 1),
#  ('f605', 1),
#  ('f63', 1),
#  ('f531', 1),
#  ('f594', 1),
#  ('f225', 1),
#  ('f219', 1),
#  ('f230', 1),
#  ('f406', 1),
#  ('f40', 1),
#  ('f1004', 1),
#  ('f522', 1),
#  ('f537', 1),
#  ('f527', 1),
#  ('f615', 1),
#  ('f292', 1),
#  ('f176', 1),
#  ('f210', 1),
#  ('f145', 1),
#  ('f1061', 1),
#  ('f538', 1),
#  ('f21', 1),
#  ('f454', 1),
#  ('f451', 1),
#  ('f206', 1),
#  ('f1041', 1),
#  ('f433', 1),
#  ('f329', 1),
#  ('f1082', 1),
#  ('f1043', 1),
#  ('f561', 1),
#  ('f272', 1),
#  ('f574', 1),
#  ('f123', 1),
#  ('f184', 1),
#  ('f4', 1),
#  ('f172', 1),
#  ('f177', 1),
#  ('f34', 1),
#  ('f293', 1),
#  ('f1080', 1),
#  ('f584', 1),
#  ('f255', 1),
#  ('f496', 1),
#  ('f479', 1),
#  ('f490', 1),
#  ('f16', 1),
#  ('f205', 1),
#  ('f346', 1),
#  ('f350', 1),
#  ('f150', 1),
#  ('f543', 1),
#  ('f91', 1),
#  ('f90', 1),
#  ('f556', 1),
#  ('f159', 1),
#  ('f582', 1),
#  ('f462', 1),
#  ('f1068', 1),
#  ('f463', 1),
#  ('f480', 1),
#  ('f105', 1),
#  ('f323', 1),
#  ('f251', 1),
#  ('f552', 1),
#  ('f80', 1),
#  ('f539', 1),
#  ('f405', 1),
#  ('f501', 1),
#  ('f575', 1),
#  ('f555', 1),
#  ('f1079', 1),
#  ('f38', 1),
#  ('f187', 1),
#  ('f182', 1),
#  ('f355', 1),
#  ('f345', 1),
#  ('f119', 1),
#  ('f359', 1),
#  ('f291', 1),
#  ('f29', 1),
#  ('f484', 1),
#  ('f36', 1),
#  ('f1098', 1),
#  ('f229', 1),
#  ('f1103', 1),
#  ('f585', 1),
#  ('f351', 1)]

# %%
list(map(lambda x:cc[x[0]], bb))
# Out:
# ['x1_2020',
#  'x4_3',
#  'x6_51',
#  'x0_567',
#  'x4_6',
#  'x0_364',
#  'x4_2',
#  'x4_4',
#  'x6_50',
#  'x0_520',
#  'x0_361',
#  'x4_1',
#  'x0_521',
#  'x2_5',
#  'x6_34',
#  'x1_2019',
#  'x2_12',
#  'x3_24',
#  'x0_382',
#  'x6_1',
#  'x4_5',
#  'x3_17',
#  'x0_24',
#  'x6_49',
#  'x2_3',
#  'x6_41',
#  'x6_25',
#  'x2_9',
#  'x0_389',
#  'x3_11',
#  'x3_9',
#  'x3_16',
#  'x6_48',
#  'x3_15',
#  'x5_1',
#  'x0_20',
#  'x1_2021',
#  'x6_44',
#  'x0_367',
#  'x0_378',
#  'x0_384',
#  'x5_4',
#  'x6_39',
#  'x3_8',
#  'x3_22',
#  'x0_379',
#  'x0_28',
#  'x0_383',
#  'x3_25',
#  'x0_381',
#  'x5_2',
#  'x0_396',
#  'x3_26',
#  'x2_1',
#  'x0_232',
#  'x6_52',
#  'x0_257',
#  'x3_6',
#  'x2_6',
#  'x5_3',
#  'x0_44',
#  'x0_328',
#  'x0_372',
#  'x3_14',
#  'x3_10',
#  'x2_11',
#  'x6_6',
#  'x0_6',
#  'x3_23',
#  'x2_8',
#  'x6_43',
#  'x6_40',
#  'x6_33',
#  'x6_13',
#  'x3_19',
#  'x0_573',
#  'x6_14',
#  'x0_313',
#  'x3_21',
#  'x6_11',
#  'x6_38',
#  'x3_1',
#  'x0_395',
#  'x6_18',
#  'x0_197',
#  'x0_7',
#  'x4_0',
#  'x3_2',
#  'x3_20',
#  'x0_18',
#  'x0_19',
#  'x0_500',
#  'x0_380',
#  'x0_258',
#  'x3_5',
#  'x6_21',
#  'x3_3',
#  'x0_629',
#  'x6_28',
#  'x0_362',
#  'x0_326',
#  'x0_169',
#  'x6_17',
#  'x0_14',
#  'x6_30',
#  'x3_4',
#  'x3_18',
#  'x0_25',
#  'x0_308',
#  'x0_470',
#  'x0_387',
#  'x6_53',
#  'x0_366',
#  'x0_268',
#  'x0_287',
#  'x0_3',
#  'x0_391',
#  'x0_10',
#  'x0_4',
#  'x0_302',
#  'x6_22',
#  'x3_13',
#  'x0_75',
#  'x6_16',
#  'x0_377',
#  'x0_221',
#  'x0_340',
#  'x6_46',
#  'x0_568',
#  'x0_201',
#  'x0_363',
#  'x0_89',
#  'x0_67',
#  'x0_465',
#  'x0_357',
#  'x6_32',
#  'x6_29',
#  'x0_597',
#  'x0_83',
#  'x0_157',
#  'x0_517',
#  'x0_307',
#  'x0_628',
#  'x0_334',
#  'x6_8',
#  'x0_359',
#  'x3_31',
#  'x3_12',
#  'x0_588',
#  'x6_10',
#  'x0_536',
#  'x0_537',
#  'x0_349',
#  'x0_522',
#  'x0_323',
#  'x0_174',
#  'x2_4',
#  'x6_27',
#  'x0_317',
#  'x0_466',
#  'x0_541',
#  'x0_479',
#  'x0_590',
#  'x0_74',
#  'x0_355',
#  'x0_116',
#  'x0_198',
#  'x0_310',
#  'x6_45',
#  'x0_29',
#  'x0_388',
#  'x6_35',
#  'x0_111',
#  'x0_114',
#  'x0_392',
#  'x0_21',
#  'x0_374',
#  'x0_76',
#  'x0_286',
#  'x0_13',
#  'x0_46',
#  'x0_518',
#  'x0_147',
#  'x0_530',
#  'x0_16',
#  'x0_110',
#  'x0_447',
#  'x0_371',
#  'x0_8',
#  'x0_373',
#  'x0_259',
#  'x3_30',
#  'x0_193',
#  'x0_331',
#  'x0_504',
#  'x0_133',
#  'x0_365',
#  'x0_312',
#  'x0_306',
#  'x0_1',
#  'x0_501',
#  'x6_9',
#  'x0_305',
#  'x0_563',
#  'x0_443',
#  'x0_261',
#  'x0_34',
#  'x0_338',
#  'x0_341',
#  'x0_288',
#  'x0_561',
#  'x0_167',
#  'x0_9',
#  'x0_284',
#  'x0_358',
#  'x0_143',
#  'x0_181',
#  'x0_168',
#  'x3_7',
#  'x0_141',
#  'x6_2',
#  'x0_405',
#  'x0_254',
#  'x0_262',
#  'x0_263',
#  'x6_31',
#  'x0_624',
#  'x0_626',
#  'x0_613',
#  'x0_609',
#  'x0_570',
#  'x0_227',
#  'x0_204',
#  'x0_599',
#  'x0_12',
#  'x6_15',
#  'x0_265',
#  'x0_129',
#  'x0_498',
#  'x0_311',
#  'x0_448',
#  'x0_79',
#  'x0_606',
#  'x0_64',
#  'x0_532',
#  'x0_595',
#  'x0_226',
#  'x0_220',
#  'x0_231',
#  'x0_407',
#  'x0_41',
#  'x2_2',
#  'x0_523',
#  'x0_538',
#  'x0_528',
#  'x0_616',
#  'x0_293',
#  'x0_177',
#  'x0_211',
#  'x0_146',
#  'x6_5',
#  'x0_539',
#  'x0_22',
#  'x0_455',
#  'x0_452',
#  'x0_207',
#  'x3_27',
#  'x0_434',
#  'x0_330',
#  'x6_26',
#  'x3_29',
#  'x0_562',
#  'x0_273',
#  'x0_575',
#  'x0_124',
#  'x0_185',
#  'x0_5',
#  'x0_173',
#  'x0_178',
#  'x0_35',
#  'x0_294',
#  'x6_24',
#  'x0_585',
#  'x0_256',
#  'x0_497',
#  'x0_480',
#  'x0_491',
#  'x0_17',
#  'x0_206',
#  'x0_347',
#  'x0_351',
#  'x0_151',
#  'x0_544',
#  'x0_92',
#  'x0_91',
#  'x0_557',
#  'x0_160',
#  'x0_583',
#  'x0_463',
#  'x6_12',
#  'x0_464',
#  'x0_481',
#  'x0_106',
#  'x0_324',
#  'x0_252',
#  'x0_553',
#  'x0_81',
#  'x0_540',
#  'x0_406',
#  'x0_502',
#  'x0_576',
#  'x0_556',
#  'x6_23',
#  'x0_39',
#  'x0_188',
#  'x0_183',
#  'x0_356',
#  'x0_346',
#  'x0_120',
#  'x0_360',
#  'x0_292',
#  'x0_30',
#  'x0_485',
#  'x0_37',
#  'x6_42',
#  'x0_230',
#  'x6_47',
#  'x0_586',
#  'x0_352']

# %%
bb = sorted(a.items(), key=lambda x: x[1], reverse=True)

# %% [markdown]
# ### xgboost api

# %%
dtest = xgb.DMatrix(x_test, y_test)

# %%
y_pred = model.predict(dtest)
print('metrics1: {:.3f}\nmetrics2: {:.3f}\nr2: {:.3f}'.format(metrics1(y_test, y_pred),
                                                              metrics2(
                                                                  y_test, y_pred),
                                                              r2_score(y_test, y_pred)))
# Out:
# metrics1: 0.939
# metrics2: 0.732
# r2: 0.858

# %%
plt.figure(figsize=(15, 4))
plt.plot(y_test.values, label='true')
plt.plot(y_pred, label='predict')
plt.xticks(rotation=90)
plt.grid()
plt.legend()

# %%
model.get_score(importance_type='gain')

# %%
xgb.to_graphviz(model, num_trees=0)

# %%
import xgboost
from xgboost import XGBClassifier
from sklearn.datasets import load_iris

iris = load_iris()
x, y = iris.data, iris.target
model = XGBClassifier()
model.fit(x, y)
# 如果输入是没有表头的array,会自动以f1,f2开始,需要更换表头
# 画树结构图的时候也需要替换表头

model.get_booster().feature_names = iris.feature_names
# max_num_features指定排名最靠前的多少特征
# height=0.2指定柱状图每个柱子的粗细,默认是0.2
# importance_type='weight'默认是用特征子树中的出现次数(被选择次数),还有"gain"和"cover"
xgboost.plot_importance(model, max_num_features=5, importance_type='gain')

# f_score就是feature score
model.feature_importances_  # 这里的特征重要性就是gain进行归一化之后的值

# %%
model.feature_importances_.sum()

# %%
2.9918/(2.9918+1.3149+0.0727+0.0424)

# %%
xgb.to_graphviz(model, num_trees=1)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(max_depth=2)

# %%
dt.fit(x, y)

# %%
import graphviz
from sklearn import tree
import pydotplus
from IPython.display import Image

# %%
# 对于决策树来说，特征重要性就等于这个特征分裂的时候的总信息增益，这个特征有可能分裂，加到一起就行
dt.feature_importances_

# %%
dot = tree.export_graphviz(dt)
graph = pydotplus.graph_from_dot_data(dot)
Image(graph.create_png())
